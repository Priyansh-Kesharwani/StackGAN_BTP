# %%
from __future__ import division
from __future__ import print_function
from __future__ import absolute_import
from __future__ import unicode_literals
import os
import os.path
import sys
import PIL
import errno
import pickle
import random
import argparse
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import time
import pprint
import datetime
import dateutil
import dateutil.tz
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
import torchvision.utils as vutils
import torchvision.transforms as transforms
from PIL import Image
from torch.nn import init
from six.moves import range
from torch.autograd import Variable
from torchvision.utils import save_image
manualSeed = random.randint(1, 10000)
random.seed(manualSeed)
torch.manual_seed(manualSeed)
torch.cuda.manual_seed_all(manualSeed)
print('random_seed: ', manualSeed)
now = datetime.datetime.now(dateutil.tz.tzlocal())
timestamp = now.strftime('%Y_%m_%d_%H_%M_%S')
print('Timestamp: ', timestamp)
# Out:
# random_seed:  674
# Timestamp:  2022_12_11_21_22_01

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d bobxxxl/coco-train-val2017
# Out:
# Downloading coco-train-val2017.zip to /content
# 100% 18.8G/18.8G [10:05<00:00, 39.6MB/s]
# 100% 18.8G/18.8G [10:05<00:00, 33.3MB/s]

# %%
# !unzip coco-train-val2017.zip -d /content/coco2014
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510343.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510351.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510358.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510383.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510395.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510449.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510515.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510527.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510548.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510559.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510579.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510585.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510587.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510593.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510606.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510609.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510616.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510636.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510642.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510643.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510651.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510657.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510681.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510707.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510719.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510734.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510735.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510755.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510782.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510791.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510798.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510827.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510838.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510842.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510852.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510857.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510861.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510864.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510871.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510877.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510898.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510915.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510942.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510955.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000510992.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511002.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511050.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511058.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511066.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511076.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511111.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511117.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511136.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511138.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511145.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511153.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511159.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511204.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511236.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511241.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511251.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511294.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511299.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511307.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511321.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511324.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511333.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511341.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511349.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511363.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511379.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511384.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511398.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511403.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511407.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511420.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511430.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511453.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511463.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511469.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511546.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511554.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511572.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511583.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511594.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511599.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511622.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511623.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511647.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511654.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511658.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511662.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511669.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511674.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511690.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511713.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511724.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511760.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511777.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511844.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511849.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511852.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511892.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511895.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511906.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511929.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000511999.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512013.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512070.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512110.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512112.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512116.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512118.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512139.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512145.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512151.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512166.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512182.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512183.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512191.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512194.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512206.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512220.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512223.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512240.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512248.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512254.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512276.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512290.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512302.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512307.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512320.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512330.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512334.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512337.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512339.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512394.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512403.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512416.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512421.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512442.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512451.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512455.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512463.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512467.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512468.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512476.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512479.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512495.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512511.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512545.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512564.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512576.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512630.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512648.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512657.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512667.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512722.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512729.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512760.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512776.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512780.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512785.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512793.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512796.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512830.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512836.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512869.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512879.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512902.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512911.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512912.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512929.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512938.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512966.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512974.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512982.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512985.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000512989.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513016.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513037.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513039.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513041.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513054.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513056.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513060.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513064.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513066.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513072.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513073.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513096.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513098.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513115.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513125.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513129.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513136.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513149.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513181.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513189.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513219.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513220.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513242.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513260.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513280.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513283.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513292.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513312.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513319.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513342.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513381.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513389.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513397.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513417.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513458.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513484.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513497.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513507.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513513.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513524.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513555.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513567.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513574.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513580.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513585.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513600.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513604.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513611.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513615.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513646.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513659.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513670.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513681.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513688.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513690.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513692.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513699.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513724.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513727.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513765.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513775.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513778.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513789.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513793.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513809.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513882.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513887.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513891.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513933.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513946.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513965.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513968.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513971.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000513993.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514016.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514018.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514049.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514082.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514083.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514089.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514097.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514116.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514118.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514147.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514173.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514180.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514200.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514222.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514241.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514248.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514249.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514254.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514271.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514292.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514294.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514296.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514321.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514366.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514376.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514396.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514402.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514416.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514417.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514437.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514464.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514468.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514483.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514504.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514508.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514518.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514525.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514529.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514537.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514540.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514550.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514586.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514598.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514600.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514604.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514607.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514668.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514681.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514682.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514685.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514690.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514722.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514731.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514773.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514787.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514797.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514826.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514860.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514901.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514904.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514913.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514914.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514915.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514979.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514982.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514984.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000514990.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515022.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515025.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515038.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515043.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515050.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515056.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515077.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515126.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515147.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515158.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515176.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515214.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515219.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515226.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515241.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515247.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515266.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515289.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515303.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515347.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515350.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515355.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515360.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515367.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515391.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515403.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515421.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515422.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515424.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515444.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515445.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515465.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515485.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515531.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515540.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515555.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515565.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515577.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515579.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515585.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515586.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515612.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515642.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515660.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515668.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515670.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515682.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515716.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515727.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515742.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515751.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515755.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515760.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515765.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515777.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515779.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515785.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515792.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515820.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515821.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515828.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515850.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515854.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515876.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515885.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515895.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515904.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515911.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515962.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515982.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000515993.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516004.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516020.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516022.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516026.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516038.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516116.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516143.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516173.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516174.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516178.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516185.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516186.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516194.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516212.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516214.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516224.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516239.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516244.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516248.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516313.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516316.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516318.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516341.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516342.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516345.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516372.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516396.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516404.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516408.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516414.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516415.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516416.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516422.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516430.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516476.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516503.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516508.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516540.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516542.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516592.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516601.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516602.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516628.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516641.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516677.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516681.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516708.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516727.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516732.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516733.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516750.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516766.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516775.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516786.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516795.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516798.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516800.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516804.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516805.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516813.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516827.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516828.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516846.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516856.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516865.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516867.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516868.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516871.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516875.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516879.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516893.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516902.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516913.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516916.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516947.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516984.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000516998.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517007.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517018.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517029.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517056.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517061.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517069.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517081.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517082.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517128.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517133.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517135.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517211.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517249.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517296.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517306.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517315.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517318.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517386.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517388.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517399.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517417.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517425.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517443.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517445.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517454.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517465.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517472.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517515.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517523.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517548.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517570.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517596.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517600.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517610.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517612.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517617.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517619.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517623.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517629.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517636.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517674.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517687.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517737.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517777.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517793.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517795.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517807.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517819.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517821.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517822.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517823.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517832.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517855.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517861.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517889.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517890.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517938.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517945.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517946.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517967.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517973.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000517987.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518006.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518027.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518030.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518034.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518039.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518109.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518116.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518127.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518133.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518140.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518163.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518177.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518182.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518188.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518197.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518203.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518213.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518222.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518224.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518234.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518249.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518255.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518262.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518287.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518324.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518326.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518348.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518363.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518365.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518375.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518377.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518383.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518438.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518440.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518524.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518530.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518551.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518574.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518584.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518586.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518592.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518604.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518605.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518615.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518701.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518716.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518719.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518721.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518725.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518729.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518770.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518773.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518818.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518836.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518850.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518873.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518889.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518899.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518908.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518914.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518916.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518937.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518968.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000518974.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000519027.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000519039.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000519046.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000519055.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000519088.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000519094.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000519112.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000519132.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000519153.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000519182.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000519193.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000519208.jpg
# ...
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578792.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578807.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578813.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578821.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578836.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578848.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578849.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578852.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578861.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578871.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578878.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578902.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578922.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578962.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578964.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578967.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578974.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578977.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578984.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000578993.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579003.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579008.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579034.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579036.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579043.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579056.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579060.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579070.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579073.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579081.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579091.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579134.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579158.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579192.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579201.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579226.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579231.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579240.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579247.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579276.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579277.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579294.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579303.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579307.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579321.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579325.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579326.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579337.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579362.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579402.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579405.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579415.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579438.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579453.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579457.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579462.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579463.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579468.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579471.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579484.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579548.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579560.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579561.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579593.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579602.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579635.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579648.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579655.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579664.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579666.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579673.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579693.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579696.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579697.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579759.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579760.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579814.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579815.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579818.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579822.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579859.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579872.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579885.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579893.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579900.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579902.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579911.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579918.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579925.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579970.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000579982.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580027.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580029.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580041.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580084.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580108.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580117.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580197.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580248.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580255.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580284.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580294.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580363.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580388.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580390.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580410.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580418.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580540.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580542.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580543.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580555.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580591.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580607.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580608.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580613.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580621.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580693.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580698.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580704.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580711.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580720.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580746.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580757.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580766.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580778.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580791.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580796.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580829.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580835.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580847.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580856.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580870.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580908.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580931.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580951.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580953.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580972.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580975.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580983.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000580986.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581010.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581022.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581033.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581040.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581062.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581081.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581087.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581100.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581157.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581177.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581180.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581183.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581205.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581206.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581226.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581245.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581253.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581262.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581317.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581328.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581332.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581338.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581356.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581357.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581394.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581401.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581402.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581415.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581422.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581437.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581450.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581451.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581458.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581482.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581496.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581501.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581542.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581557.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581560.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581569.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581593.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581615.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581632.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581654.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581655.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581683.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581702.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581717.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581726.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581731.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581736.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581749.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581781.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581827.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581829.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581831.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581863.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581886.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581887.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581899.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581913.jpg
#   inflating: /content/coco2014/val2014/val2014/COCO_val2014_000000581929.jpg

# %%
! kaggle datasets download -d rohans13/coco14
# Out:
# Downloading coco14.zip to /content
# 100% 1.47G/1.48G [00:48<00:00, 35.4MB/s]
# 100% 1.48G/1.48G [00:48<00:00, 32.8MB/s]

# %%
# !unzip coco14.zip -d /content/coco14
# Out:
# Archive:  coco14.zip
#   inflating: /content/coco14/coco/test/filename.txt
#   inflating: /content/coco14/coco/test/filenames.pickle
#   inflating: /content/coco14/coco/train/char-CNN-RNN-embeddings.pickle
#   inflating: /content/coco14/coco/train/filenames.pickle

# %%
! kaggle datasets download -d usbhavani/models
# Out:
# Downloading models.zip to /content
# 100% 404M/405M [00:14<00:00, 30.1MB/s]
# 100% 405M/405M [00:14<00:00, 30.2MB/s]

# %%
# !unzip models.zip -d /content/output
# Out:
# Archive:  models.zip
#   inflating: /content/output/coco_netG_epoch_90.pth
#   inflating: /content/output/coco_netg_epoch_90/coco_netG_epoch_90.pth

# %%
image_transform = transforms.Compose([
            transforms.RandomCrop(64),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---

# %%
pip install torchfile
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchfile
#   Downloading torchfile-0.1.0.tar.gz (5.2 kB)
# Building wheels for collected packages: torchfile
#   Building wheel for torchfile (setup.py) ... done
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5710 sha256=3625d7d450012ce4dd9a7fb27e40ffd3def0be0d3b0ae6d36867ab09d17122ad
#   Stored in directory: /root/.cache/pip/wheels/b9/99/d1/9f3f4411a958a22ccf782e33c7238a07f04a9597f2f3b38792
# Successfully built torchfile
# Installing collected packages: torchfile
# Successfully installed torchfile-0.1.0

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

from __future__ import print_function

from tensorboard import summary
from six.moves import range
from PIL import Image

from torch.autograd import Variable

from copy import deepcopy
from torch.nn import init

#!pip install torchfile

# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os


# Any results you write to the current directory are saved as output.

# ------------------------------------------------  dataset.py --------------------------------------------------

import torch.utils.data as data
from PIL import Image
import PIL
import os
import os.path
import pickle
import random
import numpy as np
import pandas as pd

class TextDataset(data.Dataset):
    def __init__(self, data_dir, split='train', embedding_type='cnn-rnn',
                 imsize=64, transform=None, target_transform=None):

        self.transform = transform
        self.target_transform = target_transform
        self.imsize = imsize
        self.data = []
        self.data_dir = data_dir
        if data_dir.find('birds') != -1:
            self.bbox = self.load_bbox()
        else:
            print('checking...')
            self.bbox = None
        split_dir = os.path.join(data_dir, split)

        self.filenames = self.load_filenames(split_dir)
        self.embeddings = self.load_embedding(split_dir, embedding_type)
        #self.class_id = self.load_class_id(split_dir, len(self.filenames))
        # self.captions = self.load_all_captions()

    def get_img(self, img_path, bbox):
        img = Image.open(img_path).convert('RGB')
        width, height = img.size
        if bbox is not None:
            R = int(np.maximum(bbox[2], bbox[3]) * 0.75)
            center_x = int((2 * bbox[0] + bbox[2]) / 2)
            center_y = int((2 * bbox[1] + bbox[3]) / 2)
            y1 = np.maximum(0, center_y - R)
            y2 = np.minimum(height, center_y + R)
            x1 = np.maximum(0, center_x - R)
            x2 = np.minimum(width, center_x + R)
            img = img.crop([x1, y1, x2, y2])
        load_size = int(self.imsize * 76 / 64)
        img = img.resize((load_size, load_size), PIL.Image.BILINEAR)
        if self.transform is not None:
            img = self.transform(img)
        return img

    def load_bbox(self):
        data_dir = self.data_dir
        bbox_path = os.path.join(data_dir, 'CUB_200_2011/bounding_boxes.txt')
        df_bounding_boxes = pd.read_csv(bbox_path,
                                        delim_whitespace=True,
                                        header=None).astype(int)
        #
        filepath = os.path.join(data_dir, 'CUB_200_2011/images.txt')
        df_filenames = \
            pd.read_csv(filepath, delim_whitespace=True, header=None)
        filenames = df_filenames[1].tolist()
        print('Total filenames: ', len(filenames), filenames[0])
        #
        filename_bbox = {img_file[:-4]: [] for img_file in filenames}
        numImgs = len(filenames)
        for i in xrange(0, numImgs):
            # bbox = [x-left, y-top, width, height]
            bbox = df_bounding_boxes.iloc[i][1:].tolist()

            key = filenames[i][:-4]
            filename_bbox[key] = bbox
        #
        return filename_bbox

    def load_all_captions(self):
        caption_dict = {}
        for key in self.filenames:
            caption_name = '%s/text/%s.txt' % (self.data_dir, key)
            captions = self.load_captions(caption_name)
            caption_dict[key] = captions
        return caption_dict

    def load_captions(self, caption_name):
        cap_path = caption_name
        with open(cap_path, "r") as f:
            captions = f.read().decode('utf8').split('\n')
        captions = [cap.replace("\ufffd\ufffd", " ")
                    for cap in captions if len(cap) > 0]
        return captions

    def load_embedding(self, data_dir, embedding_type):
        if embedding_type == 'cnn-rnn':
            print('embedding....')
            embedding_filename = os.path.join(data_dir, 'char-CNN-RNN-embeddings.pickle')
            #print(embedding_filename)
            #embedding_filename = '/char-CNN-RNN-embeddings.pickle'
        elif embedding_type == 'cnn-gru':
            embedding_filename = '/char-CNN-GRU-embeddings.pickle'
        elif embedding_type == 'skip-thought':
            embedding_filename = '/skip-thought-embeddings.pickle'

        with open(embedding_filename, 'rb') as f:
            #embeddings = pickle.load(f)
            embeddings = pickle._Unpickler(f)
            embeddings.encoding = 'latin1'
            embeddings = embeddings.load()
            #print(embeddings)
            embeddings = np.array(embeddings)
            # embedding_shape = [embeddings.shape[-1]]
        '''with open('mnist.pkl', 'rb') as f:
            u = pickle._Unpickler(f)
            u.encoding = 'latin1'
            p = u.load()'''
            #print('embeddings: ', embeddings.shape)
        return embeddings

    '''def load_class_id(self, data_dir, total_num):
        if os.path.isfile(data_dir + '/class_info.pickle'):
            with open(data_dir + '/class_info.pickle', 'rb') as f:
                class_id = pickle.load(f)
        else:
            class_id = np.arange(total_num)
        return class_id'''
    

    def load_filenames(self, data_dir):
        #../input/coco-data/coco/coco/train/filenames.pickle
        filepath = os.path.join(data_dir, 'filenames.pickle')
        with open(filepath, 'rb') as f:
            filenames = pickle.load(f)
        print('Load filenames from: %s (%d)' % (filepath, len(filenames)))
        print(len(filenames))
        print(args.IMG_DIR)
        l=os.listdir('/content/coco2014/train2014/train2014')
        im_file=[x.split('.')[0] for x in l]
        #im_file = ['.'.join(x.split('.')[:-1]) for x in os.listdir("args.IMG_DIR") if os.path.isfile(os.path.join('args.IMG_DIR', x))]
        print(len(im_file))
        #str = 'COCO_train2014_'
        #im_file = [str + x for x in im_file]
        print(im_file[0]) 
        print(filenames[0]) #COCO_train2014_
        te = list(set(im_file) & set(filenames)) 
        print('te: ', len(te))
        #list_ = ['.'.join(x.split('.')[:-1]) for x in os.listdir("path/to/Data") if os.path.isfile(os.path.join('path/to/Data', x))]
        #print(ssd)
        return filenames

    
    '''def load_filenames(self, data_dir):
        #../input/coco-data/coco/coco/train/filenames.pickle
        filepath = os.path.join(data_dir, 'filenames.pickle')
        with open(filepath, 'rb') as f:
            filenames = pickle.load(f)
        print('Load filenames from: %s (%d)' % (filepath, len(filenames)))
        return filenames'''

    def __getitem__(self, index):
        key = self.filenames[index]
        # cls_id = self.class_id[index]
        #
        if self.bbox is not None:
            bbox = self.bbox[key]
            data_dir = '%s/CUB_200_2011' % self.data_dir
        else:
            bbox = None
            data_dir = self.data_dir

        # captions = self.captions[key]
        embeddings = self.embeddings[index, :, :]
        #print(args.IMG_DIR)
        #print(key)
        #y = key[-12:]
        img_name = '%s/%s.jpg' % (args.IMG_DIR, key)
        #img_name = '%s/images/%s.jpg' % (data_dir, key)
        img = self.get_img(img_name, bbox)

        embedding_ix = random.randint(0, embeddings.shape[0]-1)
        embedding = embeddings[embedding_ix, :]
        if self.target_transform is not None:
            embedding = self.target_transform(embedding)
        return img, embedding

    def __len__(self):
        return len(self.filenames)

# ------------------------------------------------  utils.py --------------------------------------------------

import os
import errno
import numpy as np
import torch
import torch.nn as nn
import torchvision.utils as vutils

#############################
def KL_loss(mu, logvar):
    # -0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD_element = mu.pow(2).add_(logvar.exp()).mul_(-1).add_(1).add_(logvar)
    KLD = torch.mean(KLD_element).mul_(-0.5)
    return KLD


def compute_discriminator_loss(netD, real_imgs, fake_imgs,
                               real_labels, fake_labels,
                               conditions, gpus):
    criterion = nn.BCELoss()
    batch_size = real_imgs.size(0)
    cond = conditions.detach()
    fake = fake_imgs.detach()
    real_features = nn.parallel.data_parallel(netD, (real_imgs), gpus)
    fake_features = nn.parallel.data_parallel(netD, (fake), gpus)
    # real pairs
    inputs = (real_features, cond)
    real_logits = nn.parallel.data_parallel(netD.get_cond_logits, inputs, gpus)
    errD_real = criterion(real_logits, real_labels)
    # wrong pairs
    inputs = (real_features[:(batch_size-1)], cond[1:])
    wrong_logits = \
        nn.parallel.data_parallel(netD.get_cond_logits, inputs, gpus)
    errD_wrong = criterion(wrong_logits, fake_labels[1:])
    # fake pairs
    inputs = (fake_features, cond)
    fake_logits = nn.parallel.data_parallel(netD.get_cond_logits, inputs, gpus)
    errD_fake = criterion(fake_logits, fake_labels)

    if netD.get_uncond_logits is not None:
        real_logits = nn.parallel.data_parallel(netD.get_uncond_logits, (real_features), gpus)
        fake_logits = nn.parallel.data_parallel(netD.get_uncond_logits, (fake_features), gpus)
        uncond_errD_real = criterion(real_logits, real_labels)
        uncond_errD_fake = criterion(fake_logits, fake_labels)
        #
        errD = ((errD_real + uncond_errD_real) / 2. + (errD_fake + errD_wrong + uncond_errD_fake) / 3.)
        errD_real = (errD_real + uncond_errD_real) / 2.
        errD_fake = (errD_fake + uncond_errD_fake) / 2.
    else:
        errD = errD_real + (errD_fake + errD_wrong) * 0.5
    return errD, errD_real.data, errD_wrong.data, errD_fake.data


def compute_generator_loss(netD, fake_imgs, real_labels, conditions, gpus):
    criterion = nn.BCELoss()
    cond = conditions.detach()
    fake_features = nn.parallel.data_parallel(netD, (fake_imgs), gpus)
    # fake pairs
    inputs = (fake_features, cond)
    fake_logits = nn.parallel.data_parallel(netD.get_cond_logits, inputs, gpus)
    errD_fake = criterion(fake_logits, real_labels)
    if netD.get_uncond_logits is not None:
        fake_logits = \
            nn.parallel.data_parallel(netD.get_uncond_logits,
                                      (fake_features), gpus)
        uncond_errD_fake = criterion(fake_logits, real_labels)
        errD_fake += uncond_errD_fake
    return errD_fake


#############################
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        m.weight.data.normal_(1.0, 0.02)
        m.bias.data.fill_(0)
    elif classname.find('Linear') != -1:
        m.weight.data.normal_(0.0, 0.02)
        if m.bias is not None:
            m.bias.data.fill_(0.0)


#############################
def save_img_results(data_img, fake, epoch, image_dir):
    num = args.VIS_COUNT
    fake = fake[0:num]
    # data_img is changed to [0,1]
    if data_img is not None:
        data_img = data_img[0:num]
        vutils.save_image(data_img, '%s/real_samples.png' % image_dir, normalize=True)
        # fake.data is still [-1, 1]
        vutils.save_image(fake.data, '%s/fake_samples_epoch_%03d.png' % (image_dir, epoch), normalize=True)
    else:
        vutils.save_image(fake.data, '%s/lr_fake_samples_epoch_%03d.png' % (image_dir, epoch), normalize=True)


def save_model(netG, netD, epoch, model_dir):
    torch.save(
        netG.state_dict(),
        '%s/netG_epoch_%d.pth' % (model_dir, epoch))
    torch.save(
        netD.state_dict(),
        '%s/netD_epoch_last.pth' % (model_dir))
    print('Save G/D models')


def mkdir_p(path):
    try:
        os.makedirs(path)
    except OSError as exc:  # Python >2.5
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else:
            raise

# ------------------------------------------------  model.py --------------------------------------------------

import torch
import torch.nn as nn
import torch.nn.parallel
from torch.autograd import Variable


def conv3x3(in_planes, out_planes, stride=1):
    "3x3 convolution with padding"
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride, padding=1, bias=False)


# Upsale the spatial size by a factor of 2
def upBlock(in_planes, out_planes):
    block = nn.Sequential(
        nn.Upsample(scale_factor=2, mode='nearest'),
        conv3x3(in_planes, out_planes),
        nn.BatchNorm2d(out_planes),
        nn.ReLU(True))
    return block


class ResBlock(nn.Module):
    def __init__(self, channel_num):
        super(ResBlock, self).__init__()
        self.block = nn.Sequential(
            conv3x3(channel_num, channel_num),
            nn.BatchNorm2d(channel_num),
            nn.ReLU(True),
            conv3x3(channel_num, channel_num),
            nn.BatchNorm2d(channel_num))
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        residual = x
        out = self.block(x)
        out += residual
        out = self.relu(out)
        return out
class CA_NET(nn.Module):
    # some code is modified from vae examples
    # (https://github.com/pytorch/examples/blob/master/vae/main.py)
    def __init__(self):
        super(CA_NET, self).__init__()
        self.t_dim = args.DIMENSION
        self.c_dim = args.CONDITION_DIM
        self.fc = nn.Linear(self.t_dim, self.c_dim * 2, bias=True)
        self.relu = nn.ReLU()

    def encode(self, text_embedding):
        x = self.relu(self.fc(text_embedding))
        mu = x[:, :self.c_dim]
        logvar = x[:, self.c_dim:]
        return mu, logvar

    def reparametrize(self, mu, logvar):
        std = logvar.mul(0.5).exp_()
        if args.CUDA:
            eps = torch.cuda.FloatTensor(std.size()).normal_()
        else:
            eps = torch.FloatTensor(std.size()).normal_()
        eps = Variable(eps)
        return eps.mul(std).add_(mu)

    def forward(self, text_embedding):
        mu, logvar = self.encode(text_embedding)
        c_code = self.reparametrize(mu, logvar)
        return c_code, mu, logvar

class D_GET_LOGITS(nn.Module):
    def __init__(self, ndf, nef, bcondition=True):
        super(D_GET_LOGITS, self).__init__()
        self.df_dim = ndf
        self.ef_dim = nef
        self.bcondition = bcondition
        if bcondition:
            self.outlogits = nn.Sequential(
                conv3x3(ndf * 8 + nef, ndf * 8),
                nn.BatchNorm2d(ndf * 8),
                nn.LeakyReLU(0.2, inplace=True),
                nn.Conv2d(ndf * 8, 1, kernel_size=4, stride=4),
                nn.Sigmoid())
        else:
            self.outlogits = nn.Sequential(
                nn.Conv2d(ndf * 8, 1, kernel_size=4, stride=4),
                nn.Sigmoid())

    def forward(self, h_code, c_code=None):
        # conditioning output
        if self.bcondition and c_code is not None:
            c_code = c_code.view(-1, self.ef_dim, 1, 1)
            c_code = c_code.repeat(1, 1, 4, 4)
            # state size (ngf+egf) x 4 x 4
            h_c_code = torch.cat((h_code, c_code), 1)
        else:
            h_c_code = h_code

        output = self.outlogits(h_c_code)
        return output.view(-1)


# ############# Networks for stageI GAN #############
class STAGE1_G(nn.Module):
    def __init__(self):
        super(STAGE1_G, self).__init__()
        self.gf_dim = args.GF_DIM * 8
        self.ef_dim = args.CONDITION_DIM
        self.z_dim = args.Z_DIM
        self.define_module()

    def define_module(self):
        ninput = self.z_dim + self.ef_dim
        ngf = self.gf_dim
        # TEXT.DIMENSION -> GAN.CONDITION_DIM
        self.ca_net = CA_NET()

        # -> ngf x 4 x 4
        self.fc = nn.Sequential(
            nn.Linear(ninput, ngf * 4 * 4, bias=False),
            nn.BatchNorm1d(ngf * 4 * 4),
            nn.ReLU(True))

        # ngf x 4 x 4 -> ngf/2 x 8 x 8
        self.upsample1 = upBlock(ngf, ngf // 2)
        # -> ngf/4 x 16 x 16
        self.upsample2 = upBlock(ngf // 2, ngf // 4)
        # -> ngf/8 x 32 x 32
        self.upsample3 = upBlock(ngf // 4, ngf // 8)
        # -> ngf/16 x 64 x 64
        self.upsample4 = upBlock(ngf // 8, ngf // 16)
        # -> 3 x 64 x 64
        self.img = nn.Sequential(
            conv3x3(ngf // 16, 3),
            nn.Tanh())

    def forward(self, text_embedding, noise):
        c_code, mu, logvar = self.ca_net(text_embedding)
        z_c_code = torch.cat((noise, c_code), 1)
        h_code = self.fc(z_c_code)

        h_code = h_code.view(-1, self.gf_dim, 4, 4)
        h_code = self.upsample1(h_code)
        h_code = self.upsample2(h_code)
        h_code = self.upsample3(h_code)
        h_code = self.upsample4(h_code)
        # state size 3 x 64 x 64
        fake_img = self.img(h_code)
        return None, fake_img, mu, logvar


class STAGE1_D(nn.Module):
    def __init__(self):
        super(STAGE1_D, self).__init__()
        self.df_dim = args.DF_DIM
        self.ef_dim = args.CONDITION_DIM
        self.define_module()

    def define_module(self):
        ndf, nef = self.df_dim, self.ef_dim
        self.encode_img = nn.Sequential(
            nn.Conv2d(3, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf) x 32 x 32
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            # state size (ndf*2) x 16 x 16
            nn.Conv2d(ndf*2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            # state size (ndf*4) x 8 x 8
            nn.Conv2d(ndf*4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            # state size (ndf * 8) x 4 x 4)
            nn.LeakyReLU(0.2, inplace=True)
        )

        self.get_cond_logits = D_GET_LOGITS(ndf, nef)
        self.get_uncond_logits = None

    def forward(self, image):
        img_embedding = self.encode_img(image)

        return img_embedding


# ############# Networks for stageII GAN #############
class STAGE2_G(nn.Module):
    def __init__(self, STAGE1_G):
        super(STAGE2_G, self).__init__()
        self.gf_dim = args.GF_DIM
        self.ef_dim = args.CONDITION_DIM
        self.z_dim = args.Z_DIM
        self.STAGE1_G = STAGE1_G
        # fix parameters of stageI GAN
        for param in self.STAGE1_G.parameters():
            param.requires_grad = False
        self.define_module()

    def _make_layer(self, block, channel_num):
        layers = []
        for i in range(args.R_NUM):
            layers.append(block(channel_num))
        return nn.Sequential(*layers)

    def define_module(self):
        ngf = self.gf_dim
        # TEXT.DIMENSION -> GAN.CONDITION_DIM
        self.ca_net = CA_NET()
        # --> 4ngf x 16 x 16
        self.encoder = nn.Sequential(
            conv3x3(3, ngf),
            nn.ReLU(True),
            nn.Conv2d(ngf, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            nn.Conv2d(ngf * 2, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True))
        self.hr_joint = nn.Sequential(
            conv3x3(self.ef_dim + ngf * 4, ngf * 4),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True))
        self.residual = self._make_layer(ResBlock, ngf * 4)
        # --> 2ngf x 32 x 32
        self.upsample1 = upBlock(ngf * 4, ngf * 2)
        # --> ngf x 64 x 64
        self.upsample2 = upBlock(ngf * 2, ngf)
        # --> ngf // 2 x 128 x 128
        self.upsample3 = upBlock(ngf, ngf // 2)
        # --> ngf // 4 x 256 x 256
        self.upsample4 = upBlock(ngf // 2, ngf // 4)
        # --> 3 x 256 x 256
        self.img = nn.Sequential(
            conv3x3(ngf // 4, 3),
            nn.Tanh())

    def forward(self, text_embedding, noise):
        _, stage1_img, _, _ = self.STAGE1_G(text_embedding, noise)
        stage1_img = stage1_img.detach()
        encoded_img = self.encoder(stage1_img)

        c_code, mu, logvar = self.ca_net(text_embedding)
        c_code = c_code.view(-1, self.ef_dim, 1, 1)
        c_code = c_code.repeat(1, 1, 16, 16)
        i_c_code = torch.cat([encoded_img, c_code], 1)
        h_code = self.hr_joint(i_c_code)
        h_code = self.residual(h_code)

        h_code = self.upsample1(h_code)
        h_code = self.upsample2(h_code)
        h_code = self.upsample3(h_code)
        h_code = self.upsample4(h_code)

        fake_img = self.img(h_code)
        return stage1_img, fake_img, mu, logvar


class STAGE2_D(nn.Module):
    def __init__(self):
        super(STAGE2_D, self).__init__()
        self.df_dim = args.DF_DIM
        self.ef_dim = args.CONDITION_DIM
        self.define_module()

    def define_module(self):
        ndf, nef = self.df_dim, self.ef_dim
        self.encode_img = nn.Sequential(
            nn.Conv2d(3, ndf, 4, 2, 1, bias=False),  # 128 * 128 * ndf
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),  # 64 * 64 * ndf * 2
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),  # 32 * 32 * ndf * 4
            nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.2, inplace=True),  # 16 * 16 * ndf * 8
            nn.Conv2d(ndf * 8, ndf * 16, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 16),
            nn.LeakyReLU(0.2, inplace=True),  # 8 * 8 * ndf * 16
            nn.Conv2d(ndf * 16, ndf * 32, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 32),
            nn.LeakyReLU(0.2, inplace=True),  # 4 * 4 * ndf * 32
            conv3x3(ndf * 32, ndf * 16),
            nn.BatchNorm2d(ndf * 16),
            nn.LeakyReLU(0.2, inplace=True),   # 4 * 4 * ndf * 16
            conv3x3(ndf * 16, ndf * 8),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.2, inplace=True)   # 4 * 4 * ndf * 8
        )

        self.get_cond_logits = D_GET_LOGITS(ndf, nef, bcondition=True)
        self.get_uncond_logits = D_GET_LOGITS(ndf, nef, bcondition=False)

    def forward(self, image):
        img_embedding = self.encode_img(image)

        return img_embedding
    
# ------------------------------------------------  trainer.py --------------------------------------------------

import torch.backends.cudnn as cudnn
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import os
import time

import numpy as np
import torchfile

import matplotlib.pyplot as plt
from torchvision.utils import save_image

class GANTrainer(object):
    def __init__(self, output_dir):
        if args.FLAG:
            self.model_dir = os.path.join(output_dir, 'Model')
            self.image_dir = os.path.join(output_dir, 'Image')
            self.log_dir = os.path.join(output_dir, 'Log')
            mkdir_p(self.model_dir)
            mkdir_p(self.image_dir)
            mkdir_p(self.log_dir)
            #self.summary_writer = FileWriter(self.log_dir)

        self.max_epoch = args.MAX_EPOCH
        self.snapshot_interval = args.SNAPSHOT_INTERVAL

        s_gpus = args.GPU_ID.split(',')
        self.gpus = [int(ix) for ix in s_gpus]
        self.num_gpus = len(self.gpus)
        self.batch_size = args.BATCH_SIZE * self.num_gpus
        self.output_dir = output_dir
        #print(self.gpus[0])
        #torch.cuda.set_device(self.gpus[0])
        cudnn.benchmark = True
        
        # ############# For training stageI GAN #############
    def load_network_stageI(self):
        #from model import STAGE1_G, STAGE1_D
        netG = STAGE1_G()
        netG.apply(weights_init)
        print(netG)
        netD = STAGE1_D()
        netD.apply(weights_init)
        print(netD)
        print('***********************************************************')

        if args.NET_G != '':
            #state_dict = torch.load(args.NET_G, map_location=lambda storage, loc: storage)
            #netG.load_state_dict(state_dict)
            print('generator 1')
            print('Load from: ', args.NET_G)
        if args.NET_D != '':
            #state_dict = torch.load(args.NET_D,map_location=lambda storage, loc: storage)
            #netD.load_state_dict(state_dict)
            print('discriminator 1')
            print('Load from: ', args.NET_D)
        if args.CUDA:
            netG.cuda()
            netD.cuda()
        return netG, netD
        
    def load_network_stageII(self):
        #from model import STAGE1_G, STAGE2_G, STAGE2_D

        Stage1_G = STAGE1_G()
        netG = STAGE2_G(Stage1_G)
        netG.apply(weights_init)
        #print(netG)
        if args.NET_G != '':
            #state_dict = torch.load(args.NET_G,map_location=lambda storage, loc: storage)
            #netG.load_state_dict(state_dict)
            print('Load from: ', args.NET_G)
        elif args.STAGE1_G != '':
            #state_dict = torch.load(args.STAGE1_G,map_location=lambda storage, loc: storage)
            #netG.STAGE1_G.load_state_dict(state_dict)
            print('Load from: ', args.STAGE1_G)
        else:
            print("Please give the Stage1_G path")
            return

        netD = STAGE2_D()
        netD.apply(weights_init)
        if args.NET_D != '':
            #state_dict = torch.load(args.NET_D,map_location=lambda storage, loc: storage)
            #netD.load_state_dict(state_dict)
            print('Load from: ', args.NET_D)
        #print(netD)

        if args.CUDA:
            netG.cuda()
            netD.cuda()
        return netG, netD
    
    def train(self, data_loader, stage=1):
        if stage == 1:
            netG, netD = self.load_network_stageI()
        else:
            netG, netD = self.load_network_stageII()

        nz = args.Z_DIM
        batch_size = self.batch_size
        noise = Variable(torch.FloatTensor(batch_size, nz))
        fixed_noise = Variable(torch.FloatTensor(batch_size, nz).normal_(0, 1),volatile=True)
        real_labels = Variable(torch.FloatTensor(batch_size).fill_(1))
        fake_labels = Variable(torch.FloatTensor(batch_size).fill_(0))
        if args.CUDA:
            noise, fixed_noise = noise.cuda(), fixed_noise.cuda()
            real_labels, fake_labels = real_labels.cuda(), fake_labels.cuda()

        generator_lr = args.GENERATOR_LR
        discriminator_lr = args.DISCRIMINATOR_LR
        lr_decay_step = args.LR_DECAY_EPOCH
        optimizerD = optim.Adam(netD.parameters(), lr=args.DISCRIMINATOR_LR, betas=(0.5, 0.999))
        netG_para = []
        for p in netG.parameters():
            if p.requires_grad:
                netG_para.append(p)
        optimizerG = optim.Adam(netG_para,lr=args.GENERATOR_LR,betas=(0.5, 0.999))
        count = 0
        c = 0
        for epoch in range(self.max_epoch):
            if c == 1:
                break
            start_t = time.time()
            if epoch % lr_decay_step == 0 and epoch > 0:
                generator_lr *= 0.5
                for param_group in optimizerG.param_groups:
                    param_group['lr'] = generator_lr
                discriminator_lr *= 0.5
                for param_group in optimizerD.param_groups:
                    param_group['lr'] = discriminator_lr
            br = 0
            for i, data in enumerate(data_loader, 0):
                if br==3:
                    break
                ######################################################
                # (1) Prepare training data
                ######################################################
                print('data: -- ', data)
                print('---------------------')
                real_img_cpu, txt_embedding = data
                #print('embedding:  ', txt_embedding)
                real_imgs = Variable(real_img_cpu)
                txt_embedding = Variable(txt_embedding)
                #print('text_embedding:  ', txt_embedding)
                if args.CUDA:
                    real_imgs = real_imgs.cuda()
                    txt_embedding = txt_embedding.cuda()

                #######################################################
                # (2) Generate fake images
                ######################################################
                noise.data.normal_(0, 1)
                inputs = (txt_embedding, noise)
                _, fake_imgs, mu, logvar = \
                    nn.parallel.data_parallel(netG, inputs, self.gpus)

                ############################
                # (3) Update D network
                ###########################
                netD.zero_grad()
                errD, errD_real, errD_wrong, errD_fake = \
                    compute_discriminator_loss(netD, real_imgs, fake_imgs,
                                               real_labels, fake_labels,
                                               mu, self.gpus)
                errD.backward()
                optimizerD.step()
                ############################
                # (2) Update G network
                ###########################
                netG.zero_grad()
                errG = compute_generator_loss(netD, fake_imgs,
                                              real_labels, mu, self.gpus)
                kl_loss = KL_loss(mu, logvar)
                errG_total = errG + kl_loss * args.KL
                errG_total.backward()
                optimizerG.step()
                
                br = br+1
                
                count = count + 1
                if i % 10 == 0:
                    '''summary_D = summary.scalar('D_loss', errD.data)
                    summary_D_r = summary.scalar('D_loss_real', errD_real)
                    summary_D_w = summary.scalar('D_loss_wrong', errD_wrong)
                    summary_D_f = summary.scalar('D_loss_fake', errD_fake)
                    summary_G = summary.scalar('G_loss', errG.data)
                    summary_KL = summary.scalar('KL_loss', kl_loss.data)

                    self.summary_writer.add_summary(summary_D, count)
                    self.summary_writer.add_summary(summary_D_r, count)
                    self.summary_writer.add_summary(summary_D_w, count)
                    self.summary_writer.add_summary(summary_D_f, count)
                    self.summary_writer.add_summary(summary_G, count)
                    self.summary_writer.add_summary(summary_KL, count)'''

                    # save the image result for each epoch
                    inputs = (txt_embedding, fixed_noise)
                    lr_fake, fake, _, _ = nn.parallel.data_parallel(netG, inputs, self.gpus)
                    print('real_img_cpu', real_img_cpu.shape)   # real_img_cpu torch.Size([128, 3, 64, 64])
                    #print('text_embedding:  ', txt_embedding)
                    print(type(real_img_cpu))
                    print(real_img_cpu[0].shape)
                    plt.imshow(real_img_cpu[0].permute(1, 2, 0))
                    #plt.imshow(real_img_cpu[1].numpy().squeeze(), cmap='RGB')
                    #plt.imshow(real_img_cpu) 
                    '''save_img_results(real_img_cpu, fake, epoch, self.image_dir)
                    if lr_fake is not None:
                        save_img_results(None, lr_fake, epoch, self.image_dir)'''
                print('br', br)
            end_t = time.time()
            c = 1
            print('''[%d/%d][%d/%d] Loss_D: %.4f Loss_G: %.4f Loss_KL: %.4f
                     Loss_real: %.4f Loss_wrong:%.4f Loss_fake %.4f
                     Total Time: %.2fsec
                  '''
                  % (epoch, self.max_epoch, i, len(data_loader),
                     errD.data, errG.data, kl_loss.data,
                     errD_real, errD_wrong, errD_fake, (end_t - start_t)))
            if epoch % self.snapshot_interval == 0:
                save_model(netG, netD, epoch, self.model_dir)
        #
        #save_model(netG, netD, self.max_epoch, self.model_dir)
        #
        #self.summary_writer.close()'''
        
    


# ------------------------------------------------  main.py --------------------------------------------------

import torch.backends.cudnn as cudnn
import torch
import torchvision.transforms as transforms

import argparse
import os
import random
import sys
import pprint
import datetime
import dateutil
import dateutil.tz
import torchfile
    
class Struct:
    def __init__(self, **entries):
        self.__dict__.update(entries)

if __name__ == '__main__':
    params = dict()
    # parameters
    parser = argparse.ArgumentParser()
    params = dict()
    params['CONFIG_NAME']='stageI'
    params['DATASET_NAME']='coco'
    params['EMBEDDING_TYPE']='cnn-rnn'
    params['GPU_ID']='0'
    params['CUDA']='TRUE'
    params['WORKERS']=4
    params['NET_G']=''
                    #../input/models/coco_netg_epoch_90/coco_netG_epoch_90.pth
    params['NET_D']=''
    #params['STAGE1_G']='../output/coco_stageI/Model/netG_epoch_120.pth'
    params['DATA_DIR']='/content/coco14/coco'
    params['IMG_DIR'] = '/content/coco2014/train2014/train2014'
    params['VIS_COUNT']=64
    params['Z_DIM']=100
    params['IMSIZE']=64
    params['STAGE']=1
    #TRAIN = edict()
    params['FLAG']='TRUE'
    params['BATCH_SIZE']=128
    params['MAX_EPOCH']=2
    params['SNAPSHOT_INTERVAL']=1
    #params['PRETAINED_MODEL']=''
    #params['PRETRAINED_EPOCH']=600
    params['LR_DECAY_EPOCH']=20
    params['DISCRIMINATOR_LR']=0.0002
    params['GENERATOR_LR']=0.0002
    params['KL']=2.0
    #gan
    params['CONDITION_DIM']=128
    params['DF_DIM']=96
    params['GF_DIM']=192
    #params['R_NUM']=2
    #text
    params['DIMENSION']=1024
    #params['manualSeed']=random.randint(1, 10000)
    args = Struct(**params) #Convert nested Python dict to object

   # s = Struct(**params)
   # config = s             # parser.parse_args()
   # print(config)
    manualSeed = random.randint(1, 10000)
    random.seed(manualSeed)
    torch.manual_seed(manualSeed)
    torch.cuda.manual_seed_all(manualSeed)
    now = datetime.datetime.now(dateutil.tz.tzlocal())
    timestamp = now.strftime('%Y_%m_%d_%H_%M_%S')
    print(timestamp)
    
    output_dir = 'tmp/'
    #output_dir = '../output/%s_%s_%s' % (args.DATASET_NAME, args.CONFIG_NAME, timestamp)
    print(output_dir)
    num_gpu = len(args.GPU_ID.split(','))
    if args.FLAG:
        image_transform = transforms.Compose([
            transforms.RandomCrop(args.IMSIZE),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
        dataset = TextDataset(args.DATA_DIR, 'train',
                              imsize=args.IMSIZE,
                              transform=image_transform)
        assert dataset
        dataloader = torch.utils.data.DataLoader(
            dataset, batch_size=args.BATCH_SIZE * num_gpu,
            drop_last=True, shuffle=True, num_workers=int(args.WORKERS))

        algo = GANTrainer(output_dir)
        algo.train(dataloader, args.STAGE)
# Out:
# 2022_12_11_22_35_52
# tmp/
# checking...
# Load filenames from: /content/coco14/coco/train/filenames.pickle (82783)
# 82783
# /content/coco2014/train2014/train2014
# 82783
# COCO_train2014_000000505713
# COCO_train2014_000000487025
# te:  82783
# embedding....
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# STAGE1_G(
#   (ca_net): CA_NET(
#     (fc): Linear(in_features=1024, out_features=256, bias=True)
#     (relu): ReLU()
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=228, out_features=24576, bias=False)
#     (1): BatchNorm1d(24576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (upsample1): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(1536, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample2): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(768, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample3): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (upsample4): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(192, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#   )
#   (img): Sequential(
#     (0): Conv2d(96, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): Tanh()
#   )
# )
# STAGE1_D(
#   (encode_img): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(96, 192, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(192, 384, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(384, 768, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (get_cond_logits): D_GET_LOGITS(
#     (outlogits): Sequential(
#       (0): Conv2d(896, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#       (3): Conv2d(768, 1, kernel_size=(4, 4), stride=(4, 4))
#       (4): Sigmoid()
#     )
#   )
# )
# ***********************************************************
# <ipython-input-54-aabf5ba24c22>:746: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   fixed_noise = Variable(torch.FloatTensor(batch_size, nz).normal_(0, 1),volatile=True)
# data: --  [tensor([[[[-0.9922, -0.9922, -0.9922,  ...,  0.2314,  0.2706,  0.2863],
#           [-0.9843, -0.9922, -0.9922,  ...,  0.3725,  0.2784,  0.2784],
#           [-0.8824, -0.7725, -0.7020,  ..., -0.3333, -0.3882, -0.1059],
#           ...,
#           [ 0.3333,  0.3098,  0.3020,  ...,  0.0980,  0.1216,  0.0902],
#           [ 0.3176,  0.3176,  0.2941,  ...,  0.0824,  0.0902,  0.0510],
#           [ 0.2549,  0.2471,  0.2706,  ...,  0.0353,  0.0275,  0.0353]],
#
#          [[-0.6784, -0.6627, -0.6627,  ..., -0.0588, -0.0275,  0.0118],
#           [-0.6549, -0.7176, -0.6941,  ...,  0.1686,  0.0431,  0.0196],
#           [-0.2000, -0.2157, -0.1608,  ..., -0.2627, -0.3333, -0.1059],
#           ...,
#           [ 0.2392,  0.2314,  0.2157,  ...,  0.0824,  0.1059,  0.0902],
#           [ 0.2392,  0.2314,  0.2078,  ...,  0.0745,  0.0824,  0.0588],
#           [ 0.1843,  0.1686,  0.2000,  ...,  0.0510,  0.0431,  0.0588]],
#
#          [[-0.6863, -0.6706, -0.6706,  ..., -0.3490, -0.3020, -0.2627],
#           [-0.6392, -0.7176, -0.6941,  ..., -0.0118, -0.1765, -0.2235],
#           [-0.1216, -0.1373, -0.0667,  ..., -0.3490, -0.4039, -0.2000],
#           ...,
#           [ 0.0667,  0.0431,  0.0431,  ..., -0.2314, -0.2078, -0.2549],
#           [ 0.0745,  0.0745,  0.0510,  ..., -0.2627, -0.2627, -0.3098],
#           [ 0.0039, -0.0118,  0.0275,  ..., -0.3255, -0.3412, -0.3255]]],
#
#
#         [[[-0.2941, -0.2941, -0.2863,  ...,  0.4353,  0.4431,  0.4431],
#           [-0.3333, -0.3176, -0.3020,  ...,  0.4039,  0.4196,  0.4353],
#           [-0.3412, -0.3333, -0.3098,  ...,  0.2627,  0.2392,  0.2157],
#           ...,
#           [ 0.0824, -0.0902, -0.3569,  ..., -0.3569, -0.4118, -0.4431],
#           [ 0.0824, -0.0667, -0.3333,  ..., -0.2863, -0.3412, -0.3804],
#           [ 0.0745, -0.0196, -0.3176,  ..., -0.2471, -0.2941, -0.3647]],
#
#          [[-0.1451, -0.1294, -0.1059,  ...,  0.4431,  0.4431,  0.4588],
#           [-0.1765, -0.1529, -0.1373,  ...,  0.3961,  0.4196,  0.4353],
#           [-0.2157, -0.1843, -0.1686,  ...,  0.3176,  0.2941,  0.2863],
#           ...,
#           [-0.1216, -0.2706, -0.5059,  ..., -0.4980, -0.5294, -0.5843],
#           [-0.1294, -0.2471, -0.5059,  ..., -0.4745, -0.5137, -0.5529],
#           [-0.1294, -0.2078, -0.4902,  ..., -0.4667, -0.5059, -0.5373]],
#
#          [[ 0.0196,  0.0510,  0.0510,  ...,  0.3804,  0.3882,  0.3882],
#           [-0.0039,  0.0196,  0.0196,  ...,  0.3412,  0.3490,  0.3569],
#           [-0.0431, -0.0275, -0.0118,  ...,  0.3176,  0.3020,  0.2863],
#           ...,
#           [-0.3569, -0.4745, -0.6706,  ..., -0.6784, -0.7098, -0.7490],
#           [-0.3647, -0.4824, -0.6941,  ..., -0.6784, -0.6784, -0.7098],
#           [-0.3569, -0.4353, -0.6549,  ..., -0.6471, -0.6706, -0.7098]]],
#
#
#         [[[ 0.4431,  0.4980,  0.5451,  ...,  0.2235,  0.2078,  0.2549],
#           [-0.1137,  0.0510,  0.2157,  ...,  0.1765,  0.1451,  0.1765],
#           [ 0.0902,  0.1686,  0.2471,  ...,  0.1451,  0.2000,  0.2549],
#           ...,
#           [ 0.8824,  0.8588,  0.8353,  ...,  0.9137,  0.9059,  0.8980],
#           [ 0.8824,  0.8745,  0.8824,  ...,  0.8980,  0.8902,  0.8902],
#           [ 0.8667,  0.8745,  0.8745,  ...,  0.8902,  0.8824,  0.8667]],
#
#          [[ 0.4118,  0.4510,  0.4824,  ...,  0.3255,  0.3176,  0.3255],
#           [ 0.0118,  0.1608,  0.2627,  ...,  0.2078,  0.2078,  0.1922],
#           [ 0.1294,  0.2157,  0.2863,  ...,  0.1765,  0.2078,  0.2235],
#           ...,
#           [ 0.4980,  0.4745,  0.5137,  ...,  0.4980,  0.4902,  0.4745],
#           [ 0.5059,  0.4980,  0.5294,  ...,  0.4902,  0.4745,  0.4745],
#           [ 0.4902,  0.4980,  0.4980,  ...,  0.4745,  0.4510,  0.4431]],
#
#          [[ 0.0902,  0.0980,  0.1765,  ..., -0.0824, -0.0980, -0.0588],
#           [-0.5451, -0.4118, -0.2078,  ..., -0.1922, -0.1608, -0.1294],
#           [-0.3882, -0.3490, -0.3176,  ..., -0.3020, -0.2706, -0.2314],
#           ...,
#           [ 0.2314,  0.2235,  0.3098,  ...,  0.1922,  0.1765,  0.1608],
#           [ 0.2392,  0.2392,  0.2941,  ...,  0.1843,  0.1765,  0.1686],
#           [ 0.2157,  0.2314,  0.2392,  ...,  0.1686,  0.1373,  0.1294]]],
#
#
#         ...,
#
#
#         [[[ 0.3020,  0.3098,  0.3020,  ..., -0.1608, -0.1686, -0.1059],
#           [ 0.5373,  0.5373,  0.5294,  ..., -0.1216, -0.0824, -0.0824],
#           [ 0.5529,  0.5529,  0.5529,  ..., -0.1137, -0.0824, -0.0824],
#           ...,
#           [ 0.3176,  0.3098,  0.2863,  ...,  0.2706,  0.2627,  0.2706],
#           [ 0.2863,  0.2941,  0.2941,  ...,  0.2314,  0.2314,  0.2235],
#           [ 0.2471,  0.2706,  0.2706,  ...,  0.1765,  0.1765,  0.1843]],
#
#          [[ 0.3255,  0.3255,  0.3176,  ..., -0.1137, -0.1216, -0.0510],
#           [ 0.6078,  0.6078,  0.6000,  ..., -0.0824, -0.0353, -0.0431],
#           [ 0.6314,  0.6314,  0.6314,  ..., -0.0745, -0.0510, -0.0667],
#           ...,
#           [ 0.3098,  0.3020,  0.2706,  ...,  0.2549,  0.2471,  0.2549],
#           [ 0.2784,  0.2863,  0.2863,  ...,  0.2157,  0.2157,  0.2078],
#           [ 0.2392,  0.2627,  0.2627,  ...,  0.1608,  0.1608,  0.1686]],
#
#          [[ 0.3255,  0.3333,  0.3255,  ..., -0.1059, -0.1137, -0.0431],
#           [ 0.6627,  0.6627,  0.6549,  ..., -0.0588, -0.0275, -0.0353],
#           [ 0.6941,  0.7020,  0.6941,  ..., -0.0745, -0.0510, -0.0667],
#           ...,
#           [ 0.3020,  0.2941,  0.2784,  ...,  0.2627,  0.2549,  0.2627],
#           [ 0.2627,  0.2706,  0.2706,  ...,  0.2235,  0.2235,  0.2157],
#           [ 0.2235,  0.2471,  0.2471,  ...,  0.1686,  0.1686,  0.1765]]],
#
#
#         [[[-0.7020, -0.7098, -0.7961,  ...,  0.2784,  0.2549,  0.2314],
#           [-0.5765, -0.7176, -0.8039,  ...,  0.2627,  0.2314,  0.1922],
#           [-0.6941, -0.8196, -0.8275,  ...,  0.2392,  0.2157,  0.1686],
#           ...,
#           [ 0.9373,  0.8902,  0.8824,  ..., -0.4039, -0.3961, -0.3961],
#           [ 0.8980,  0.9137,  0.9216,  ..., -0.4275, -0.4196, -0.3961],
#           [ 0.9373,  0.9451,  0.9529,  ..., -0.3882, -0.4118, -0.3961]],
#
#          [[-0.7176, -0.7569, -0.8353,  ...,  0.0588,  0.0510,  0.0275],
#           [-0.6235, -0.7333, -0.8275,  ...,  0.0588,  0.0510,  0.0118],
#           [-0.7412, -0.8275, -0.8510,  ...,  0.0510,  0.0353,  0.0118],
#           ...,
#           [ 0.7961,  0.7412,  0.7098,  ..., -0.3176, -0.3255, -0.3176],
#           [ 0.7255,  0.7647,  0.7725,  ..., -0.3176, -0.3176, -0.3098],
#           [ 0.7882,  0.8118,  0.8275,  ..., -0.3176, -0.3176, -0.3255]],
#
#          [[-0.8275, -0.8510, -0.8667,  ..., -0.4196, -0.4039, -0.3961],
#           [-0.7569, -0.8431, -0.8588,  ..., -0.4118, -0.4118, -0.4196],
#           [-0.8431, -0.8824, -0.8588,  ..., -0.4275, -0.4196, -0.4196],
#           ...,
#           [ 0.2941,  0.2314,  0.2000,  ..., -0.3961, -0.3961, -0.3961],
#           [ 0.2078,  0.2549,  0.2627,  ..., -0.4039, -0.4039, -0.3961],
#           [ 0.2706,  0.3098,  0.3412,  ..., -0.4118, -0.4118, -0.4196]]],
#
#
#         [[[ 0.6078,  0.6078,  0.6078,  ...,  0.4902,  0.4745,  0.4510],
#           [ 0.6157,  0.6157,  0.6157,  ...,  0.4824,  0.4588,  0.4431],
#           [ 0.6157,  0.6157,  0.6157,  ...,  0.4588,  0.4431,  0.4196],
#           ...,
#           [-0.5765, -0.5765, -0.5216,  ...,  0.2078,  0.2549,  0.1686],
#           [-0.6000, -0.6157, -0.5843,  ...,  0.1216,  0.2078,  0.0353],
#           [-0.6078, -0.6784, -0.5922,  ..., -0.0275,  0.1922,  0.1451]],
#
#          [[ 0.7412,  0.7333,  0.7412,  ...,  0.6471,  0.6314,  0.6314],
#           [ 0.7412,  0.7412,  0.7412,  ...,  0.6314,  0.6157,  0.6157],
#           [ 0.7412,  0.7412,  0.7412,  ...,  0.6078,  0.6078,  0.5922],
#           ...,
#           [-0.5765, -0.5765, -0.5294,  ...,  0.2235,  0.2784,  0.1922],
#           [-0.5922, -0.6235, -0.6000,  ...,  0.1373,  0.2235,  0.0431],
#           [-0.6000, -0.6941, -0.6157,  ..., -0.0118,  0.2078,  0.1529]],
#
#          [[ 0.8510,  0.8510,  0.8510,  ...,  0.8353,  0.8275,  0.8196],
#           [ 0.8510,  0.8510,  0.8588,  ...,  0.8039,  0.8039,  0.8039],
#           [ 0.8431,  0.8510,  0.8588,  ...,  0.7725,  0.7882,  0.7804],
#           ...,
#           [-0.7098, -0.7176, -0.6549,  ...,  0.1608,  0.2392,  0.1373],
#           [-0.7255, -0.7569, -0.7333,  ...,  0.0824,  0.1765, -0.0196],
#           [-0.7333, -0.8431, -0.7490,  ..., -0.0745,  0.1608,  0.0980]]]]), tensor([[-0.0456,  0.0072, -0.0978,  ...,  0.0298,  0.0165, -0.0131],
#         [-0.1312, -0.0135,  0.1532,  ...,  0.0563,  0.0214, -0.0187],
#         [ 0.1785,  0.0338,  0.0305,  ..., -0.0196, -0.1224, -0.0349],
#         ...,
#         [ 0.0448,  0.0014,  0.0812,  ..., -0.0842, -0.0143,  0.0210],
#         [ 0.1731,  0.0301,  0.2560,  ...,  0.0867, -0.0536,  0.0131],
#         [ 0.1960,  0.0635, -0.1450,  ...,  0.0052,  0.0058, -0.0328]])]
# ---------------------
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# real_img_cpu torch.Size([128, 3, 64, 64])
# <class 'torch.Tensor'>
# torch.Size([3, 64, 64])
# br 1
# data: --  [tensor([[[[-0.0118, -0.0275, -0.0039,  ..., -0.8745, -0.6000, -0.3647],
#           [ 0.0039, -0.0039,  0.0118,  ..., -0.7490, -0.4039, -0.5294],
#           [ 0.0039,  0.0196,  0.0275,  ..., -0.4902, -0.4510, -0.7725],
#           ...,
#           [-0.3490, -0.3647, -0.2392,  ...,  0.6078,  0.3020,  0.0353],
#           [-0.3569, -0.3961, -0.2471,  ...,  0.4196,  0.1216,  0.0196],
#           [-0.3725, -0.3804, -0.1922,  ...,  0.2078, -0.0510, -0.0275]],
#
#          [[-0.0118, -0.0431, -0.0039,  ..., -0.8667, -0.6157, -0.3804],
#           [ 0.0039, -0.0196,  0.0039,  ..., -0.7490, -0.4275, -0.5451],
#           [ 0.0118,  0.0196,  0.0353,  ..., -0.5059, -0.4667, -0.7725],
#           ...,
#           [-0.3725, -0.3882, -0.2627,  ...,  0.2235, -0.0980, -0.2863],
#           [-0.3882, -0.4196, -0.2549,  ...,  0.0039, -0.2784, -0.2863],
#           [-0.4039, -0.3882, -0.2000,  ..., -0.1922, -0.4039, -0.2706]],
#
#          [[-0.0588, -0.1059, -0.0510,  ..., -0.8745, -0.6549, -0.4431],
#           [-0.0353, -0.0667, -0.0353,  ..., -0.7725, -0.4824, -0.5922],
#           [-0.0275, -0.0196, -0.0118,  ..., -0.5373, -0.5137, -0.7961],
#           ...,
#           [-0.4118, -0.4275, -0.2941,  ...,  0.0196, -0.3176, -0.4275],
#           [-0.4196, -0.4510, -0.2863,  ..., -0.1843, -0.4431, -0.3961],
#           [-0.4275, -0.4196, -0.2314,  ..., -0.3569, -0.5529, -0.3490]]],
#
#
#         [[[-0.2471, -0.2235, -0.1843,  ...,  1.0000,  1.0000,  1.0000],
#           [-0.3725, -0.2784, -0.2471,  ...,  1.0000,  1.0000,  1.0000],
#           [-0.4275, -0.4902, -0.4431,  ...,  1.0000,  1.0000,  1.0000],
#           ...,
#           [-0.0353, -0.0353, -0.0431,  ..., -0.4745, -0.4039, -0.3647],
#           [-0.0510, -0.0588, -0.0431,  ..., -0.2784, -0.2549, -0.2627],
#           [-0.0353, -0.0353, -0.0353,  ..., -0.1294, -0.1373, -0.1529]],
#
#          [[-0.2392, -0.1373, -0.0196,  ...,  0.9608,  0.9608,  0.9608],
#           [-0.4039, -0.3333, -0.2941,  ...,  0.9608,  0.9608,  0.9608],
#           [-0.4353, -0.5059, -0.4745,  ...,  0.9608,  0.9608,  0.9608],
#           ...,
#           [ 0.0510,  0.0275,  0.0196,  ..., -0.4039, -0.3098, -0.2627],
#           [-0.0118, -0.0039,  0.0275,  ..., -0.1922, -0.1529, -0.1373],
#           [ 0.0196,  0.0275,  0.0431,  ..., -0.0510, -0.0431, -0.0431]],
#
#          [[-0.1608, -0.0118,  0.1451,  ...,  0.9373,  0.9373,  0.9373],
#           [-0.3804, -0.3020, -0.2314,  ...,  0.9373,  0.9373,  0.9373],
#           [-0.3882, -0.4824, -0.4431,  ...,  0.9373,  0.9373,  0.9373],
#           ...,
#           [ 0.1373,  0.1059,  0.0980,  ..., -0.3725, -0.2549, -0.1843],
#           [ 0.0431,  0.0588,  0.0980,  ..., -0.1216, -0.0745, -0.0510],
#           [ 0.0745,  0.0902,  0.1137,  ...,  0.0196,  0.0431,  0.0431]]],
#
#
#         [[[-0.2706, -0.2549, -0.3647,  ...,  0.2784,  0.2392,  0.2157],
#           [-0.4588, -0.5922, -0.6863,  ...,  0.2549,  0.1765,  0.1451],
#           [-0.7412, -0.7098, -0.6863,  ...,  0.3176,  0.0118,  0.0431],
#           ...,
#           [-0.9059, -0.9137, -0.8980,  ...,  0.6549,  0.5843,  0.4980],
#           [-0.9216, -0.8980, -0.8902,  ...,  0.7098,  0.6706,  0.5608],
#           [-0.9137, -0.8902, -0.8824,  ...,  0.6941,  0.6000,  0.5059]],
#
#          [[-0.3255, -0.3098, -0.4353,  ...,  0.0588,  0.0118, -0.0275],
#           [-0.4980, -0.6471, -0.7647,  ...,  0.0667, -0.0588, -0.1059],
#           [-0.8118, -0.7882, -0.7882,  ...,  0.2000, -0.1922, -0.2157],
#           ...,
#           [-0.9529, -0.9451, -0.9451,  ...,  0.6078,  0.5373,  0.4510],
#           [-0.9529, -0.9529, -0.9451,  ...,  0.6863,  0.6392,  0.5137],
#           [-0.9529, -0.9529, -0.9529,  ...,  0.6706,  0.5686,  0.4510]],
#
#          [[-0.3255, -0.3412, -0.5137,  ..., -0.1137, -0.1608, -0.1922],
#           [-0.4980, -0.6627, -0.7882,  ..., -0.0667, -0.2078, -0.2784],
#           [-0.8353, -0.8275, -0.8196,  ...,  0.1294, -0.3176, -0.3804],
#           ...,
#           [-0.9765, -0.9843, -0.9686,  ...,  0.5529,  0.4588,  0.3804],
#           [-0.9843, -0.9765, -0.9686,  ...,  0.6471,  0.6000,  0.4510],
#           [-0.9843, -0.9765, -0.9686,  ...,  0.6392,  0.5294,  0.3804]]],
#
#
#         ...,
#
#
#         [[[ 0.5059,  0.5137,  0.5373,  ...,  0.0275, -0.0824, -0.0667],
#           [ 0.6471,  0.6000,  0.7412,  ..., -0.2784, -0.1922,  0.3098],
#           [ 0.7333,  0.7020,  0.7882,  ..., -0.3412, -0.1059,  0.4039],
#           ...,
#           [ 0.8510,  0.8588,  0.8667,  ...,  0.8588,  0.8353,  0.8196],
#           [ 0.8510,  0.8510,  0.8667,  ...,  0.8510,  0.8353,  0.8118],
#           [ 0.8510,  0.8588,  0.8588,  ...,  0.8431,  0.8275,  0.8039]],
#
#          [[ 0.4431,  0.4353,  0.5137,  ..., -0.3569, -0.4667, -0.5451],
#           [ 0.6157,  0.5608,  0.7255,  ..., -0.5843, -0.5373, -0.2235],
#           [ 0.6235,  0.6157,  0.6549,  ..., -0.6627, -0.4824,  0.0275],
#           ...,
#           [ 0.8824,  0.8824,  0.8745,  ...,  0.8902,  0.8745,  0.8588],
#           [ 0.8824,  0.8824,  0.8824,  ...,  0.8902,  0.8745,  0.8510],
#           [ 0.8824,  0.8824,  0.8902,  ...,  0.8824,  0.8667,  0.8431]],
#
#          [[ 0.4275,  0.3647,  0.4196,  ..., -0.6000, -0.6863, -0.7020],
#           [ 0.6078,  0.5294,  0.7333,  ..., -0.7020, -0.6392, -0.3333],
#           [ 0.6314,  0.6078,  0.6784,  ..., -0.7098, -0.5686, -0.1294],
#           ...,
#           [ 0.9059,  0.9059,  0.9059,  ...,  0.9137,  0.8980,  0.8824],
#           [ 0.9059,  0.9059,  0.9137,  ...,  0.9137,  0.8980,  0.8745],
#           [ 0.9059,  0.9059,  0.9137,  ...,  0.9059,  0.8902,  0.8667]]],
#
#
#         [[[ 0.8745,  0.8745,  0.8824,  ...,  0.7569,  0.7412,  0.7098],
#           [ 0.8902,  0.9059,  0.9059,  ...,  0.7804,  0.7647,  0.7490],
#           [ 0.9059,  0.9059,  0.9216,  ...,  0.7804,  0.7725,  0.7647],
#           ...,
#           [-0.2392, -0.1529, -0.1137,  ..., -0.5529, -0.5216, -0.4667],
#           [-0.4824, -0.4353, -0.3412,  ..., -0.2627, -0.3569, -0.3412],
#           [-0.5451, -0.5216, -0.4902,  ..., -0.0588, -0.3176, -0.4118]],
#
#          [[ 0.9686,  0.9765,  0.9765,  ...,  0.8745,  0.8588,  0.8353],
#           [ 0.9765,  0.9843,  0.9843,  ...,  0.8902,  0.8824,  0.8667],
#           [ 0.9843,  0.9843,  0.9843,  ...,  0.8980,  0.8902,  0.8824],
#           ...,
#           [-0.4275, -0.3804, -0.3569,  ..., -0.6549, -0.6627, -0.6235],
#           [-0.5922, -0.5451, -0.4745,  ..., -0.4431, -0.5922, -0.5922],
#           [-0.6000, -0.5843, -0.5608,  ..., -0.2314, -0.4980, -0.6549]],
#
#          [[ 0.9922,  0.9922,  0.9922,  ...,  0.9686,  0.9608,  0.9529],
#           [ 0.9922,  0.9922,  0.9922,  ...,  0.9765,  0.9765,  0.9686],
#           [ 1.0000,  0.9922,  1.0000,  ...,  0.9843,  0.9765,  0.9765],
#           ...,
#           [-0.5608, -0.5451, -0.5373,  ..., -0.7412, -0.7569, -0.7255],
#           [-0.6627, -0.6235, -0.5686,  ..., -0.6078, -0.7255, -0.7412],
#           [-0.6549, -0.6314, -0.6235,  ..., -0.3569, -0.6078, -0.7882]]],
#
#
#         [[[ 0.1373,  0.1608,  0.1922,  ...,  0.1059,  0.0745,  0.0667],
#           [ 0.1529,  0.1843,  0.1765,  ...,  0.1451,  0.0745,  0.0353],
#           [ 0.1765,  0.1922,  0.1922,  ...,  0.1922,  0.1294,  0.0431],
#           ...,
#           [-0.1137, -0.2235, -0.3412,  ..., -0.1843, -0.1765, -0.1608],
#           [-0.0745, -0.1137, -0.2235,  ..., -0.1686, -0.1608, -0.1765],
#           [-0.0196, -0.0667, -0.1216,  ..., -0.1373, -0.1529, -0.1922]],
#
#          [[ 0.1059,  0.1529,  0.1843,  ...,  0.1137,  0.0824,  0.0667],
#           [ 0.1373,  0.1608,  0.1843,  ...,  0.1451,  0.0824,  0.0745],
#           [ 0.1451,  0.1608,  0.1686,  ...,  0.1765,  0.1216,  0.0902],
#           ...,
#           [ 0.0510, -0.0745, -0.2235,  ..., -0.1373, -0.1373, -0.1529],
#           [ 0.0824,  0.0431, -0.0824,  ..., -0.1137, -0.1294, -0.1451],
#           [ 0.0980,  0.0824,  0.0353,  ..., -0.1216, -0.1451, -0.1294]],
#
#          [[-0.2000, -0.1451, -0.1294,  ..., -0.0353, -0.0510, -0.0431],
#           [-0.1686, -0.1216, -0.1686,  ..., -0.0118, -0.0824, -0.0667],
#           [-0.1373, -0.1373, -0.1294,  ...,  0.0039, -0.0510, -0.1137],
#           ...,
#           [-0.1059, -0.2471, -0.4745,  ..., -0.2471, -0.2549, -0.2627],
#           [-0.0745, -0.1294, -0.3255,  ..., -0.2471, -0.2627, -0.2235],
#           [-0.0824, -0.0980, -0.1373,  ..., -0.2471, -0.2784, -0.2784]]]]), tensor([[-0.2748, -0.0040,  0.1871,  ...,  0.1886,  0.0449,  0.0624],
#         [-0.1503, -0.0148,  0.2875,  ...,  0.1467,  0.0639,  0.1178],
#         [ 0.0041,  0.0553,  0.0946,  ...,  0.0634, -0.0253,  0.0463],
#         ...,
#         [ 0.0753, -0.0063,  0.1693,  ...,  0.0105, -0.0100,  0.0068],
#         [ 0.1422,  0.1040,  0.1022,  ...,  0.0135, -0.0471, -0.0341],
#         [ 0.0232,  0.0058,  0.2354,  ...,  0.0445, -0.0413,  0.0602]])]
# ---------------------
# br 2
# data: --  [tensor([[[[ 0.0745,  0.0353,  0.0353,  ...,  0.2078,  0.2157,  0.1922],
#           [ 0.1216,  0.1059,  0.0824,  ...,  0.3255,  0.3020,  0.2627],
#           [ 0.4275,  0.5608,  0.3961,  ...,  0.4039,  0.3569,  0.3333],
#           ...,
#           [-0.1137, -0.0980, -0.0902,  ..., -0.0980, -0.1373, -0.1608],
#           [-0.1216, -0.0980, -0.0902,  ..., -0.0745, -0.0902, -0.1373],
#           [-0.1294, -0.1059, -0.1059,  ..., -0.0588, -0.0745, -0.0902]],
#
#          [[-0.2314, -0.2392, -0.2392,  ..., -0.1608, -0.1608, -0.1608],
#           [-0.2000, -0.2235, -0.2157,  ..., -0.0980, -0.1137, -0.1137],
#           [ 0.0118,  0.0980, -0.0196,  ..., -0.0510, -0.0667, -0.0745],
#           ...,
#           [-0.1608, -0.1373, -0.1216,  ..., -0.1451, -0.1765, -0.1686],
#           [-0.1608, -0.1451, -0.1216,  ..., -0.0980, -0.1294, -0.1608],
#           [-0.1686, -0.1451, -0.1216,  ..., -0.0745, -0.0980, -0.1216]],
#
#          [[-0.5216, -0.5137, -0.5059,  ..., -0.5059, -0.4902, -0.4667],
#           [-0.5373, -0.5373, -0.5059,  ..., -0.4902, -0.4745, -0.4588],
#           [-0.4667, -0.4588, -0.5059,  ..., -0.4824, -0.4667, -0.4510],
#           ...,
#           [-0.2941, -0.2706, -0.2471,  ..., -0.1686, -0.2000, -0.2078],
#           [-0.2941, -0.2627, -0.2314,  ..., -0.1137, -0.1451, -0.1922],
#           [-0.3020, -0.2627, -0.2314,  ..., -0.0667, -0.1059, -0.1451]]],
#
#
#         [[[ 0.7647,  0.7647,  0.7647,  ...,  0.2235,  0.2235,  0.2549],
#           [ 0.7647,  0.7647,  0.7647,  ...,  0.2000,  0.1765,  0.1765],
#           [ 0.7647,  0.7647,  0.7569,  ...,  0.0980,  0.1373,  0.1843],
#           ...,
#           [ 0.3647,  0.3412,  0.3333,  ...,  0.2235,  0.1765,  0.1608],
#           [ 0.3412,  0.3569,  0.3569,  ...,  0.1529,  0.1608,  0.1843],
#           [ 0.2706,  0.3255,  0.3490,  ..., -0.0902, -0.0275,  0.0118]],
#
#          [[ 0.7647,  0.7647,  0.7647,  ..., -0.3176, -0.2549, -0.1059],
#           [ 0.7647,  0.7647,  0.7647,  ..., -0.3961, -0.3804, -0.3255],
#           [ 0.7647,  0.7647,  0.7569,  ..., -0.4980, -0.4196, -0.2549],
#           ...,
#           [-0.1451, -0.1373, -0.1294,  ..., -0.2235, -0.2863, -0.3020],
#           [-0.1373, -0.1451, -0.1216,  ..., -0.0902, -0.1137, -0.1216],
#           [ 0.0353, -0.1373, -0.1608,  ..., -0.1059, -0.0431, -0.0353]],
#
#          [[ 0.7647,  0.7647,  0.7647,  ..., -0.7020, -0.6314, -0.4353],
#           [ 0.7647,  0.7647,  0.7647,  ..., -0.7176, -0.7020, -0.6627],
#           [ 0.7647,  0.7647,  0.7490,  ..., -0.7255, -0.6314, -0.4353],
#           ...,
#           [-0.6941, -0.6627, -0.6314,  ..., -0.7176, -0.7176, -0.7020],
#           [-0.6157, -0.6784, -0.6706,  ..., -0.4353, -0.4824, -0.5373],
#           [-0.1059, -0.5922, -0.7020,  ..., -0.1059, -0.0510, -0.0980]]],
#
#
#         [[[ 0.3882,  0.3882,  0.4353,  ...,  0.5294,  0.4824,  0.5294],
#           [ 0.4039,  0.4196,  0.4353,  ...,  0.5137,  0.5137,  0.4980],
#           [ 0.3961,  0.4118,  0.4039,  ...,  0.5451,  0.5451,  0.5608],
#           ...,
#           [-0.3961, -0.4196, -0.3961,  ..., -0.8510, -0.8510, -0.8431],
#           [-0.4196, -0.4196, -0.3412,  ..., -0.7490, -0.8510, -0.8588],
#           [-0.4275, -0.3098, -0.3098,  ..., -0.5294, -0.7412, -0.8667]],
#
#          [[ 0.3647,  0.3725,  0.4118,  ...,  0.4902,  0.4431,  0.4902],
#           [ 0.3725,  0.3882,  0.4039,  ...,  0.4902,  0.4824,  0.4667],
#           [ 0.3804,  0.3961,  0.3804,  ...,  0.4980,  0.5059,  0.5294],
#           ...,
#           [-0.5765, -0.6235, -0.6157,  ..., -0.8588, -0.8588, -0.8510],
#           [-0.6235, -0.6235, -0.5686,  ..., -0.7882, -0.8667, -0.8667],
#           [-0.6235, -0.5373, -0.5294,  ..., -0.6314, -0.7804, -0.8745]],
#
#          [[ 0.2549,  0.2549,  0.2941,  ...,  0.3412,  0.3020,  0.3412],
#           [ 0.2549,  0.2706,  0.2863,  ...,  0.3725,  0.3725,  0.3412],
#           [ 0.2784,  0.2863,  0.2627,  ...,  0.3490,  0.3647,  0.4039],
#           ...,
#           [-0.7804, -0.8431, -0.8510,  ..., -0.8902, -0.8824, -0.8745],
#           [-0.8431, -0.8510, -0.8118,  ..., -0.8353, -0.8902, -0.8980],
#           [-0.8588, -0.7961, -0.7725,  ..., -0.7569, -0.8353, -0.8980]]],
#
#
#         ...,
#
#
#         [[[-0.8431, -0.8745, -0.8980,  ...,  0.3961,  0.3882,  0.3804],
#           [-0.8510, -0.8353, -0.7647,  ...,  0.4118,  0.3961,  0.3882],
#           [-0.8510, -0.8118, -0.7804,  ...,  0.4118,  0.4039,  0.4039],
#           ...,
#           [-0.5843, -0.5686, -0.5529,  ..., -0.5294, -0.6157, -0.4275],
#           [-0.5608, -0.5608, -0.5529,  ..., -0.6392, -0.6627, -0.6235],
#           [-0.5451, -0.5608, -0.5529,  ..., -0.5686, -0.5686, -0.5451]],
#
#          [[-0.8275, -0.8510, -0.8902,  ...,  0.6314,  0.6314,  0.6235],
#           [-0.8353, -0.8196, -0.7490,  ...,  0.6392,  0.6392,  0.6314],
#           [-0.8431, -0.8039, -0.7569,  ...,  0.6471,  0.6471,  0.6392],
#           ...,
#           [-0.5686, -0.5686, -0.5529,  ..., -0.5059, -0.6078, -0.4039],
#           [-0.5608, -0.5608, -0.5451,  ..., -0.6392, -0.6627, -0.6235],
#           [-0.5451, -0.5529, -0.5451,  ..., -0.5686, -0.5686, -0.5451]],
#
#          [[-0.8510, -0.8745, -0.8980,  ...,  0.8588,  0.8510,  0.8431],
#           [-0.8588, -0.8353, -0.7490,  ...,  0.8667,  0.8588,  0.8510],
#           [-0.8667, -0.8275, -0.7647,  ...,  0.8667,  0.8667,  0.8667],
#           ...,
#           [-0.5922, -0.5843, -0.5686,  ..., -0.7882, -0.7020, -0.7961],
#           [-0.5765, -0.5765, -0.5686,  ..., -0.7255, -0.7098, -0.7020],
#           [-0.5608, -0.5765, -0.5765,  ..., -0.6157, -0.6078, -0.5922]]],
#
#
#         [[[-0.5765, -0.6941, -0.7333,  ..., -0.4588, -0.6549, -0.7098],
#           [-0.6706, -0.6863, -0.6941,  ..., -0.5922, -0.6549, -0.5373],
#           [-0.7255, -0.6392, -0.6549,  ..., -0.5608, -0.6000, -0.2706],
#           ...,
#           [-0.4196, -0.4353, -0.4431,  ..., -0.6549, -0.6549, -0.6392],
#           [-0.2627, -0.2627, -0.1922,  ..., -0.5922, -0.6235, -0.5608],
#           [-0.0902, -0.0745, -0.1059,  ..., -0.5137, -0.4588, -0.6078]],
#
#          [[-0.5686, -0.6706, -0.7176,  ..., -0.2392, -0.5216, -0.6549],
#           [-0.6471, -0.6549, -0.6627,  ..., -0.3882, -0.5451, -0.5137],
#           [-0.7020, -0.6000, -0.6157,  ..., -0.3725, -0.4745, -0.1843],
#           ...,
#           [-0.1216, -0.0745, -0.0275,  ..., -0.3804, -0.3882, -0.3020],
#           [ 0.1137,  0.1059,  0.1765,  ..., -0.2706, -0.3176, -0.2000],
#           [ 0.3098,  0.3098,  0.2784,  ..., -0.1608, -0.1294, -0.2471]],
#
#          [[-0.6392, -0.7176, -0.7569,  ..., -0.5529, -0.7020, -0.7020],
#           [-0.6863, -0.7020, -0.6941,  ..., -0.6078, -0.6706, -0.6078],
#           [-0.7098, -0.6314, -0.6471,  ..., -0.5529, -0.6157, -0.5294],
#           ...,
#           [-0.5686, -0.6000, -0.6863,  ..., -0.6392, -0.6392, -0.6000],
#           [-0.5529, -0.5451, -0.5373,  ..., -0.5922, -0.5451, -0.5294],
#           [-0.4824, -0.4824, -0.5451,  ..., -0.5137, -0.3882, -0.6235]]],
#
#
#         [[[-0.7569, -0.6784, -0.6863,  ...,  0.0980, -0.0039, -0.0196],
#           [-0.7569, -0.6392, -0.6078,  ...,  0.0980,  0.0196,  0.0118],
#           [-0.6235, -0.6784, -0.6627,  ...,  0.1059,  0.0196,  0.0196],
#           ...,
#           [-0.8902, -0.7961, -0.6784,  ..., -0.6863, -0.6000, -0.4902],
#           [-0.8824, -0.8118, -0.7020,  ..., -0.6863, -0.6000, -0.4980],
#           [-0.8745, -0.8275, -0.7333,  ..., -0.7020, -0.5922, -0.4980]],
#
#          [[-0.9216, -0.8667, -0.8745,  ..., -0.4039, -0.4745, -0.4902],
#           [-0.9216, -0.8275, -0.8039,  ..., -0.4039, -0.4667, -0.4824],
#           [-0.8745, -0.8824, -0.8275,  ..., -0.4039, -0.4745, -0.4667],
#           ...,
#           [-0.9765, -0.9529, -0.9294,  ..., -0.9451, -0.9216, -0.8902],
#           [-0.9686, -0.9608, -0.9294,  ..., -0.9373, -0.9216, -0.8902],
#           [-0.9686, -0.9608, -0.9294,  ..., -0.9451, -0.9216, -0.8902]],
#
#          [[-0.9373, -0.8980, -0.9216,  ..., -0.8118, -0.7961, -0.7961],
#           [-0.9373, -0.8667, -0.8667,  ..., -0.7882, -0.7804, -0.7804],
#           [-0.9059, -0.9059, -0.8588,  ..., -0.7961, -0.7961, -0.7725],
#           ...,
#           [-0.9843, -0.9765, -0.9608,  ..., -0.9765, -0.9765, -0.9843],
#           [-0.9765, -0.9686, -0.9529,  ..., -0.9843, -0.9843, -0.9765],
#           [-0.9843, -0.9686, -0.9373,  ..., -0.9843, -0.9843, -0.9765]]]]), tensor([[ 1.0285e-01, -1.9687e-04, -2.7661e-02,  ..., -5.6122e-02,
#           5.6810e-02, -1.8765e-02],
#         [-5.3076e-02,  6.2719e-02,  1.8760e-01,  ...,  6.7693e-02,
#           2.1490e-02, -3.5120e-02],
#         [ 6.8161e-02,  3.6587e-02,  1.4305e-01,  ...,  4.6016e-02,
#          -3.2582e-02, -2.8996e-02],
#         ...,
#         [ 9.5489e-02,  9.0655e-02, -4.9566e-02,  ..., -4.0957e-02,
#          -7.0673e-02, -1.0389e-01],
#         [ 1.2835e-01, -5.8363e-03,  1.6791e-01,  ...,  3.5819e-02,
#           4.5628e-02,  6.6531e-02],
#         [ 3.9223e-01,  8.8851e-02,  2.5673e-01,  ...,  1.6302e-01,
#           1.6929e-01,  5.7795e-02]])]
# ---------------------
# br 3
# [0/2][3/646] Loss_D: 3.4784 Loss_G: 5.7224 Loss_KL: 0.0029
#                      Loss_real: 2.8178 Loss_wrong:0.8886 Loss_fake 0.4327
#                      Total Time: 24.53sec
#
# Save G/D models

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

from __future__ import print_function

from tensorboard import summary
from six.moves import range
from PIL import Image

from torch.autograd import Variable

from copy import deepcopy
from torch.nn import init

#!pip install torchfile

# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os


# Any results you write to the current directory are saved as output.

# ------------------------------------------------  dataset.py --------------------------------------------------

import torch.utils.data as data
from PIL import Image
import PIL
import os
import os.path
import pickle
import random
import numpy as np
import pandas as pd

class TextDataset(data.Dataset):
    def __init__(self, data_dir, split='train', embedding_type='cnn-rnn',
                 imsize=256, transform=None, target_transform=None):

        self.transform = transform
        self.target_transform = target_transform
        self.imsize = imsize
        self.data = []
        self.data_dir = data_dir
        if data_dir.find('birds') != -1:
            self.bbox = self.load_bbox()
        else:
            print('checking...')
            self.bbox = None
        split_dir = os.path.join(data_dir, split)

        self.filenames = self.load_filenames(split_dir)
        self.embeddings = self.load_embedding(split_dir, embedding_type)
        #self.class_id = self.load_class_id(split_dir, len(self.filenames))
        # self.captions = self.load_all_captions()

    def get_img(self, img_path, bbox):
        img = Image.open(img_path).convert('RGB')
        width, height = img.size
        if bbox is not None:
            R = int(np.maximum(bbox[2], bbox[3]) * 0.75)
            center_x = int((2 * bbox[0] + bbox[2]) / 2)
            center_y = int((2 * bbox[1] + bbox[3]) / 2)
            y1 = np.maximum(0, center_y - R)
            y2 = np.minimum(height, center_y + R)
            x1 = np.maximum(0, center_x - R)
            x2 = np.minimum(width, center_x + R)
            img = img.crop([x1, y1, x2, y2])
        load_size = int(self.imsize * 76 / 64)
        img = img.resize((load_size, load_size), PIL.Image.BILINEAR)
        if self.transform is not None:
            img = self.transform(img)
        return img

    def load_bbox(self):
        data_dir = self.data_dir
        bbox_path = os.path.join(data_dir, 'CUB_200_2011/bounding_boxes.txt')
        df_bounding_boxes = pd.read_csv(bbox_path,
                                        delim_whitespace=True,
                                        header=None).astype(int)
        #
        filepath = os.path.join(data_dir, 'CUB_200_2011/images.txt')
        df_filenames = \
            pd.read_csv(filepath, delim_whitespace=True, header=None)
        filenames = df_filenames[1].tolist()
        print('Total filenames: ', len(filenames), filenames[0])
        #
        filename_bbox = {img_file[:-4]: [] for img_file in filenames}
        numImgs = len(filenames)
        for i in xrange(0, numImgs):
            # bbox = [x-left, y-top, width, height]
            bbox = df_bounding_boxes.iloc[i][1:].tolist()

            key = filenames[i][:-4]
            filename_bbox[key] = bbox
        #
        return filename_bbox

    def load_all_captions(self):
        caption_dict = {}
        for key in self.filenames:
            caption_name = '%s/text/%s.txt' % (self.data_dir, key)
            captions = self.load_captions(caption_name)
            caption_dict[key] = captions
        return caption_dict

    def load_captions(self, caption_name):
        cap_path = caption_name
        with open(cap_path, "r") as f:
            captions = f.read().decode('utf8').split('\n')
        captions = [cap.replace("\ufffd\ufffd", " ")
                    for cap in captions if len(cap) > 0]
        return captions

    def load_embedding(self, data_dir, embedding_type):
        if embedding_type == 'cnn-rnn':
            print('embedding....')
            embedding_filename = os.path.join(data_dir, 'char-CNN-RNN-embeddings.pickle')
            #print(embedding_filename)
            #embedding_filename = '/char-CNN-RNN-embeddings.pickle'
        elif embedding_type == 'cnn-gru':
            embedding_filename = '/char-CNN-GRU-embeddings.pickle'
        elif embedding_type == 'skip-thought':
            embedding_filename = '/skip-thought-embeddings.pickle'

        with open(embedding_filename, 'rb') as f:
            #embeddings = pickle.load(f)
            embeddings = pickle._Unpickler(f)
            embeddings.encoding = 'latin1'
            embeddings = embeddings.load()[1:500]
            #print(embeddings)
            embeddings = np.array(embeddings)
            print('embeddings: ', embeddings.shape)
            # embedding_shape = [embeddings.shape[-1]]
        '''with open('mnist.pkl', 'rb') as f:
            u = pickle._Unpickler(f)
            u.encoding = 'latin1'
            p = u.load()'''
            
            
        return embeddings

    '''def load_class_id(self, data_dir, total_num):
        if os.path.isfile(data_dir + '/class_info.pickle'):
            with open(data_dir + '/class_info.pickle', 'rb') as f:
                class_id = pickle.load(f)
        else:
            class_id = np.arange(total_num)
        return class_id'''
    

    def load_filenames(self, data_dir):
        #../input/coco-data/coco/coco/train/filenames.pickle
        filepath = os.path.join(data_dir, 'filenames.pickle')
        with open(filepath, 'rb') as f:
            filenames = pickle.load(f)[1:500]
        print('Load filenames from: %s (%d)' % (filepath, len(filenames)))
        print(len(filenames))
        #print(args.IMG_DIR)
        #l=os.listdir('../input/coco-train-val2017/train2014/train2014')
        #im_file=[x.split('.')[0] for x in l]
        #im_file = ['.'.join(x.split('.')[:-1]) for x in os.listdir("args.IMG_DIR") if os.path.isfile(os.path.join('args.IMG_DIR', x))]
        #print(len(im_file))
        #str = 'COCO_train2014_'
        #im_file = [str + x for x in im_file]
        #print(im_file[0]) 
        print(filenames[0]) #COCO_train2014_
        #te = list(set(im_file) & set(filenames)) 
        #print('te: ', len(te))
        #list_ = ['.'.join(x.split('.')[:-1]) for x in os.listdir("path/to/Data") if os.path.isfile(os.path.join('path/to/Data', x))]
        #print(ssd)
        return filenames

    
    '''def load_filenames(self, data_dir):
        #../input/coco-data/coco/coco/train/filenames.pickle
        filepath = os.path.join(data_dir, 'filenames.pickle')
        with open(filepath, 'rb') as f:
            filenames = pickle.load(f)
        print('Load filenames from: %s (%d)' % (filepath, len(filenames)))
        return filenames'''

    def __getitem__(self, index):
        key = self.filenames[index]
        # cls_id = self.class_id[index]
        #
        if self.bbox is not None:
            bbox = self.bbox[key]
            data_dir = '%s/CUB_200_2011' % self.data_dir
        else:
            bbox = None
            data_dir = self.data_dir

        # captions = self.captions[key]
        embeddings = self.embeddings[index, :, :]
        #print(args.IMG_DIR)
        #print(key)
        #y = key[-12:]
        img_name = '%s/%s.jpg' % (args.IMG_DIR, key)
        #img_name = '%s/images/%s.jpg' % (data_dir, key)
        img = self.get_img(img_name, bbox)

        embedding_ix = random.randint(0, embeddings.shape[0]-1)
        embedding = embeddings[embedding_ix, :]
        if self.target_transform is not None:
            embedding = self.target_transform(embedding)
        return img, embedding

    def __len__(self):
        return len(self.filenames)

# ------------------------------------------------  utils.py --------------------------------------------------

import os
import errno
import numpy as np
import torch
import torch.nn as nn
import torchvision.utils as vutils

#############################
def KL_loss(mu, logvar):
    # -0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD_element = mu.pow(2).add_(logvar.exp()).mul_(-1).add_(1).add_(logvar)
    KLD = torch.mean(KLD_element).mul_(-0.5)
    return KLD


def compute_discriminator_loss(netD, real_imgs, fake_imgs,
                               real_labels, fake_labels,
                               conditions, gpus):
    criterion = nn.BCELoss()
    batch_size = real_imgs.size(0)
    cond = conditions.detach()
    fake = fake_imgs.detach()
    real_features = nn.parallel.data_parallel(netD, (real_imgs), gpus)
    fake_features = nn.parallel.data_parallel(netD, (fake), gpus)
    # real pairs
    inputs = (real_features, cond)
    real_logits = nn.parallel.data_parallel(netD.get_cond_logits, inputs, gpus)
    errD_real = criterion(real_logits, real_labels)
    # wrong pairs
    inputs = (real_features[:(batch_size-1)], cond[1:])
    wrong_logits = \
        nn.parallel.data_parallel(netD.get_cond_logits, inputs, gpus)
    errD_wrong = criterion(wrong_logits, fake_labels[1:])
    # fake pairs
    inputs = (fake_features, cond)
    fake_logits = nn.parallel.data_parallel(netD.get_cond_logits, inputs, gpus)
    errD_fake = criterion(fake_logits, fake_labels)

    if netD.get_uncond_logits is not None:
        real_logits = nn.parallel.data_parallel(netD.get_uncond_logits, (real_features), gpus)
        fake_logits = nn.parallel.data_parallel(netD.get_uncond_logits, (fake_features), gpus)
        uncond_errD_real = criterion(real_logits, real_labels)
        uncond_errD_fake = criterion(fake_logits, fake_labels)
        #
        errD = ((errD_real + uncond_errD_real) / 2. + (errD_fake + errD_wrong + uncond_errD_fake) / 3.)
        errD_real = (errD_real + uncond_errD_real) / 2.
        errD_fake = (errD_fake + uncond_errD_fake) / 2.
    else:
        errD = errD_real + (errD_fake + errD_wrong) * 0.5
    return errD, errD_real.data, errD_wrong.data, errD_fake.data


def compute_generator_loss(netD, fake_imgs, real_labels, conditions, gpus):
    criterion = nn.BCELoss()
    cond = conditions.detach()
    fake_features = nn.parallel.data_parallel(netD, (fake_imgs), gpus)
    # fake pairs
    inputs = (fake_features, cond)
    fake_logits = nn.parallel.data_parallel(netD.get_cond_logits, inputs, gpus)
    errD_fake = criterion(fake_logits, real_labels)
    if netD.get_uncond_logits is not None:
        fake_logits = \
            nn.parallel.data_parallel(netD.get_uncond_logits,
                                      (fake_features), gpus)
        uncond_errD_fake = criterion(fake_logits, real_labels)
        errD_fake += uncond_errD_fake
    return errD_fake


#############################
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        m.weight.data.normal_(1.0, 0.02)
        m.bias.data.fill_(0)
    elif classname.find('Linear') != -1:
        m.weight.data.normal_(0.0, 0.02)
        if m.bias is not None:
            m.bias.data.fill_(0.0)


#############################
def save_img_results(data_img, fake, epoch, image_dir):
    num = args.VIS_COUNT
    fake = fake[0:num]
    # data_img is changed to [0,1]
    if data_img is not None:
        data_img = data_img[0:num]
        vutils.save_image(data_img, '%s/real_samples.png' % image_dir, normalize=True)
        # fake.data is still [-1, 1]
        vutils.save_image(fake.data, '%s/fake_samples_epoch_%03d.png' % (image_dir, epoch), normalize=True)
    else:
        vutils.save_image(fake.data, '%s/lr_fake_samples_epoch_%03d.png' % (image_dir, epoch), normalize=True)


def save_model(netG, netD, epoch, model_dir):
    torch.save(
        netG.state_dict(),
        '%s/netG_epoch_%d.pth' % (model_dir, epoch))
    torch.save(
        netD.state_dict(),
        '%s/netD_epoch_last.pth' % (model_dir))
    print('Save G/D models')


def mkdir_p(path):
    try:
        os.makedirs(path)
    except OSError as exc:  # Python >2.5
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else:
            raise

# ------------------------------------------------  model.py --------------------------------------------------

import torch
import torch.nn as nn
import torch.nn.parallel
from torch.autograd import Variable


def conv3x3(in_planes, out_planes, stride=1):
    "3x3 convolution with padding"
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride, padding=1, bias=False)


# Upsale the spatial size by a factor of 2
def upBlock(in_planes, out_planes):
    block = nn.Sequential(
        nn.Upsample(scale_factor=2, mode='nearest'),
        conv3x3(in_planes, out_planes),
        nn.BatchNorm2d(out_planes),
        nn.ReLU(True))
    return block


class ResBlock(nn.Module):
    def __init__(self, channel_num):
        super(ResBlock, self).__init__()
        self.block = nn.Sequential(
            conv3x3(channel_num, channel_num),
            nn.BatchNorm2d(channel_num),
            nn.ReLU(True),
            conv3x3(channel_num, channel_num),
            nn.BatchNorm2d(channel_num))
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        residual = x
        out = self.block(x)
        out += residual
        out = self.relu(out)
        return out
class CA_NET(nn.Module):
    # some code is modified from vae examples
    # (https://github.com/pytorch/examples/blob/master/vae/main.py)
    def __init__(self):
        super(CA_NET, self).__init__()
        self.t_dim = args.DIMENSION
        self.c_dim = args.CONDITION_DIM
        self.fc = nn.Linear(self.t_dim, self.c_dim * 2, bias=True)
        self.relu = nn.ReLU()

    def encode(self, text_embedding):
        x = self.relu(self.fc(text_embedding))
        mu = x[:, :self.c_dim]
        logvar = x[:, self.c_dim:]
        return mu, logvar

    def reparametrize(self, mu, logvar):
        std = logvar.mul(0.5).exp_()
        if args.CUDA:
            eps = torch.cuda.FloatTensor(std.size()).normal_()
        else:
            eps = torch.FloatTensor(std.size()).normal_()
        eps = Variable(eps)
        return eps.mul(std).add_(mu)

    def forward(self, text_embedding):
        mu, logvar = self.encode(text_embedding)
        c_code = self.reparametrize(mu, logvar)
        return c_code, mu, logvar

class D_GET_LOGITS(nn.Module):
    def __init__(self, ndf, nef, bcondition=True):
        super(D_GET_LOGITS, self).__init__()
        self.df_dim = ndf
        self.ef_dim = nef
        self.bcondition = bcondition
        if bcondition:
            self.outlogits = nn.Sequential(
                conv3x3(ndf * 8 + nef, ndf * 8),
                nn.BatchNorm2d(ndf * 8),
                nn.LeakyReLU(0.2, inplace=True),
                nn.Conv2d(ndf * 8, 1, kernel_size=4, stride=4),
                nn.Sigmoid())
        else:
            self.outlogits = nn.Sequential(
                nn.Conv2d(ndf * 8, 1, kernel_size=4, stride=4),
                nn.Sigmoid())

    def forward(self, h_code, c_code=None):
        # conditioning output
        if self.bcondition and c_code is not None:
            c_code = c_code.view(-1, self.ef_dim, 1, 1)
            c_code = c_code.repeat(1, 1, 4, 4)
            # state size (ngf+egf) x 4 x 4
            h_c_code = torch.cat((h_code, c_code), 1)
        else:
            h_c_code = h_code

        output = self.outlogits(h_c_code)
        return output.view(-1)


# ############# Networks for stageI GAN #############
class STAGE1_G(nn.Module):
    def __init__(self):
        super(STAGE1_G, self).__init__()
        self.gf_dim = args.GF_DIM * 8
        self.ef_dim = args.CONDITION_DIM
        self.z_dim = args.Z_DIM
        self.define_module()

    def define_module(self):
        ninput = self.z_dim + self.ef_dim
        ngf = self.gf_dim
        # TEXT.DIMENSION -> GAN.CONDITION_DIM
        self.ca_net = CA_NET()

        # -> ngf x 4 x 4
        self.fc = nn.Sequential(
            nn.Linear(ninput, ngf * 4 * 4, bias=False),
            nn.BatchNorm1d(ngf * 4 * 4),
            nn.ReLU(True))

        # ngf x 4 x 4 -> ngf/2 x 8 x 8
        self.upsample1 = upBlock(ngf, ngf // 2)
        # -> ngf/4 x 16 x 16
        self.upsample2 = upBlock(ngf // 2, ngf // 4)
        # -> ngf/8 x 32 x 32
        self.upsample3 = upBlock(ngf // 4, ngf // 8)
        # -> ngf/16 x 64 x 64
        self.upsample4 = upBlock(ngf // 8, ngf // 16)
        # -> 3 x 64 x 64
        self.img = nn.Sequential(
            conv3x3(ngf // 16, 3),
            nn.Tanh())

    def forward(self, text_embedding, noise):
        c_code, mu, logvar = self.ca_net(text_embedding)
        z_c_code = torch.cat((noise, c_code), 1)
        h_code = self.fc(z_c_code)

        h_code = h_code.view(-1, self.gf_dim, 4, 4)
        h_code = self.upsample1(h_code)
        h_code = self.upsample2(h_code)
        h_code = self.upsample3(h_code)
        h_code = self.upsample4(h_code)
        # state size 3 x 64 x 64
        fake_img = self.img(h_code)
        return None, fake_img, mu, logvar


class STAGE1_D(nn.Module):
    def __init__(self):
        super(STAGE1_D, self).__init__()
        self.df_dim = args.DF_DIM
        self.ef_dim = args.CONDITION_DIM
        self.define_module()

    def define_module(self):
        ndf, nef = self.df_dim, self.ef_dim
        self.encode_img = nn.Sequential(
            nn.Conv2d(3, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf) x 32 x 32
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            # state size (ndf*2) x 16 x 16
            nn.Conv2d(ndf*2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            # state size (ndf*4) x 8 x 8
            nn.Conv2d(ndf*4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            # state size (ndf * 8) x 4 x 4)
            nn.LeakyReLU(0.2, inplace=True)
        )

        self.get_cond_logits = D_GET_LOGITS(ndf, nef)
        self.get_uncond_logits = None

    def forward(self, image):
        img_embedding = self.encode_img(image)

        return img_embedding


# ############# Networks for stageII GAN #############
class STAGE2_G(nn.Module):
    def __init__(self, STAGE1_G):
        super(STAGE2_G, self).__init__()
        self.gf_dim = args.GF_DIM
        self.ef_dim = args.CONDITION_DIM
        self.z_dim = args.Z_DIM
        self.STAGE1_G = STAGE1_G
        # fix parameters of stageI GAN
        for param in self.STAGE1_G.parameters():
            param.requires_grad = False
        self.define_module()

    def _make_layer(self, block, channel_num):
        layers = []
        for i in range(args.R_NUM):
            layers.append(block(channel_num))
        return nn.Sequential(*layers)

    def define_module(self):
        ngf = self.gf_dim
        # TEXT.DIMENSION -> GAN.CONDITION_DIM
        self.ca_net = CA_NET()
        # --> 4ngf x 16 x 16
        self.encoder = nn.Sequential(
            conv3x3(3, ngf),
            nn.ReLU(True),
            nn.Conv2d(ngf, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            nn.Conv2d(ngf * 2, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True))
        self.hr_joint = nn.Sequential(
            conv3x3(self.ef_dim + ngf * 4, ngf * 4),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True))
        self.residual = self._make_layer(ResBlock, ngf * 4)
        # --> 2ngf x 32 x 32
        self.upsample1 = upBlock(ngf * 4, ngf * 2)
        # --> ngf x 64 x 64
        self.upsample2 = upBlock(ngf * 2, ngf)
        # --> ngf // 2 x 128 x 128
        self.upsample3 = upBlock(ngf, ngf // 2)
        # --> ngf // 4 x 256 x 256
        self.upsample4 = upBlock(ngf // 2, ngf // 4)
        # --> 3 x 256 x 256
        self.img = nn.Sequential(
            conv3x3(ngf // 4, 3),
            nn.Tanh())

    def forward(self, text_embedding, noise):
        _, stage1_img, _, _ = self.STAGE1_G(text_embedding, noise)
        stage1_img = stage1_img.detach()
        encoded_img = self.encoder(stage1_img)

        c_code, mu, logvar = self.ca_net(text_embedding)
        c_code = c_code.view(-1, self.ef_dim, 1, 1)
        c_code = c_code.repeat(1, 1, 16, 16)
        i_c_code = torch.cat([encoded_img, c_code], 1)
        h_code = self.hr_joint(i_c_code)
        h_code = self.residual(h_code)

        h_code = self.upsample1(h_code)
        h_code = self.upsample2(h_code)
        h_code = self.upsample3(h_code)
        h_code = self.upsample4(h_code)

        fake_img = self.img(h_code)
        return stage1_img, fake_img, mu, logvar


class STAGE2_D(nn.Module):
    def __init__(self):
        super(STAGE2_D, self).__init__()
        self.df_dim = args.DF_DIM
        self.ef_dim = args.CONDITION_DIM
        self.define_module()

    def define_module(self):
        ndf, nef = self.df_dim, self.ef_dim
        self.encode_img = nn.Sequential(
            nn.Conv2d(3, ndf, 4, 2, 1, bias=False),  # 128 * 128 * ndf
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),  # 64 * 64 * ndf * 2
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),  # 32 * 32 * ndf * 4
            nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.2, inplace=True),  # 16 * 16 * ndf * 8
            nn.Conv2d(ndf * 8, ndf * 16, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 16),
            nn.LeakyReLU(0.2, inplace=True),  # 8 * 8 * ndf * 16
            nn.Conv2d(ndf * 16, ndf * 32, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 32),
            nn.LeakyReLU(0.2, inplace=True),  # 4 * 4 * ndf * 32
            conv3x3(ndf * 32, ndf * 16),
            nn.BatchNorm2d(ndf * 16),
            nn.LeakyReLU(0.2, inplace=True),   # 4 * 4 * ndf * 16
            conv3x3(ndf * 16, ndf * 8),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.2, inplace=True)   # 4 * 4 * ndf * 8
        )

        self.get_cond_logits = D_GET_LOGITS(ndf, nef, bcondition=True)
        self.get_uncond_logits = D_GET_LOGITS(ndf, nef, bcondition=False)

    def forward(self, image):
        img_embedding = self.encode_img(image)

        return img_embedding
    
# ------------------------------------------------  trainer.py --------------------------------------------------

import torch.backends.cudnn as cudnn
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import os
import time

import numpy as np
#import torchfile

import matplotlib.pyplot as plt
from torchvision.utils import save_image

class GANTrainer(object):
    def __init__(self, output_dir):
        if args.FLAG:
            self.model_dir = os.path.join(output_dir, 'Model')
            self.image_dir = os.path.join(output_dir, 'Image')
            self.log_dir = os.path.join(output_dir, 'Log')
            mkdir_p(self.model_dir)
            mkdir_p(self.image_dir)
            mkdir_p(self.log_dir)
            #self.summary_writer = FileWriter(self.log_dir)

        self.max_epoch = args.MAX_EPOCH
        self.snapshot_interval = args.SNAPSHOT_INTERVAL

        s_gpus = args.GPU_ID.split(',')
        self.gpus = [int(ix) for ix in s_gpus]
        self.num_gpus = len(self.gpus)
        self.batch_size = args.BATCH_SIZE * self.num_gpus
        self.output_dir = output_dir
        #print(self.gpus[0])
        #torch.cuda.set_device(self.gpus[0])
        cudnn.benchmark = True
        
        # ############# For training stageI GAN #############
    def load_network_stageI(self):
        #from model import STAGE1_G, STAGE1_D
        netG = STAGE1_G()
        netG.apply(weights_init)
        print(netG)
        netD = STAGE1_D()
        netD.apply(weights_init)
        print(netD)
        print('***********************************************************')

        if args.NET_G != '':
            #state_dict = torch.load(args.NET_G, map_location=lambda storage, loc: storage)
            #netG.load_state_dict(state_dict)
            print('generator 1')
            print('Load from: ', args.NET_G)
        if args.NET_D != '':
            #state_dict = torch.load(args.NET_D,map_location=lambda storage, loc: storage)
            #netD.load_state_dict(state_dict)
            print('discriminator 1')
            print('Load from: ', args.NET_D)
        if args.CUDA:
            netG.cuda()
            netD.cuda()
        return netG, netD
        
    def load_network_stageII(self):
        #from model import STAGE1_G, STAGE2_G, STAGE2_D

        Stage1_G = STAGE1_G()
        netG = STAGE2_G(Stage1_G)
        netG.apply(weights_init)
        #print(netG)
        if args.NET_G != '':
            #state_dict = torch.load(args.NET_G,map_location=lambda storage, loc: storage)
            #netG.load_state_dict(state_dict)
            print('Load from: ', args.NET_G)
        elif args.STAGE1_G != '':
            state_dict = torch.load(args.STAGE1_G,map_location=lambda storage, loc: storage)
            netG.STAGE1_G.load_state_dict(state_dict)
            print('Load from: ', args.STAGE1_G)
        else:
            print("Please give the Stage1_G path")
            return

        netD = STAGE2_D()
        netD.apply(weights_init)
        if args.NET_D != '':
            #state_dict = torch.load(args.NET_D,map_location=lambda storage, loc: storage)
            #netD.load_state_dict(state_dict)
            print('Load from: ', args.NET_D)
        #print(netD)

        if args.CUDA:
            netG.cuda()
            netD.cuda()
        return netG, netD
    
    def train(self, data_loader, stage=1):
        if stage == 1:
            netG, netD = self.load_network_stageI()
        else:
            netG, netD = self.load_network_stageII()

        nz = args.Z_DIM
        batch_size = self.batch_size
        noise = Variable(torch.FloatTensor(batch_size, nz))
        fixed_noise = Variable(torch.FloatTensor(batch_size, nz).normal_(0, 1),volatile=True)
        real_labels = Variable(torch.FloatTensor(batch_size).fill_(1))
        fake_labels = Variable(torch.FloatTensor(batch_size).fill_(0))
        if args.CUDA:
            noise, fixed_noise = noise.cuda(), fixed_noise.cuda()
            real_labels, fake_labels = real_labels.cuda(), fake_labels.cuda()

        generator_lr = args.GENERATOR_LR
        discriminator_lr = args.DISCRIMINATOR_LR
        lr_decay_step = args.LR_DECAY_EPOCH
        optimizerD = optim.Adam(netD.parameters(), lr=args.DISCRIMINATOR_LR, betas=(0.5, 0.999))
        netG_para = []
        for p in netG.parameters():
            if p.requires_grad:
                netG_para.append(p)
        optimizerG = optim.Adam(netG_para,lr=args.GENERATOR_LR,betas=(0.5, 0.999))
        count = 0
        c = 0
        for epoch in range(self.max_epoch):
            if c == 1:
                break
            start_t = time.time()
            if epoch % lr_decay_step == 0 and epoch > 0:
                generator_lr *= 0.5
                for param_group in optimizerG.param_groups:
                    param_group['lr'] = generator_lr
                discriminator_lr *= 0.5
                for param_group in optimizerD.param_groups:
                    param_group['lr'] = discriminator_lr
            br = 0
            for i, data in enumerate(data_loader, 0):
                if br==3:
                    break
                ######################################################
                # (1) Prepare training data
                ######################################################
                #print('data: -- ', data)
                print('---------------------')
                real_img_cpu, txt_embedding = data
                #print('embedding:  ', txt_embedding)
                real_imgs = Variable(real_img_cpu)
                txt_embedding = Variable(txt_embedding)
                #print('text_embedding:  ', txt_embedding)
                if args.CUDA:
                    real_imgs = real_imgs.cuda()
                    txt_embedding = txt_embedding.cuda()

                #######################################################
                # (2) Generate fake images
                ######################################################
                noise.data.normal_(0, 1)
                inputs = (txt_embedding, noise)
                _, fake_imgs, mu, logvar = \
                    nn.parallel.data_parallel(netG, inputs, self.gpus)

                print(fake_imgs[0].detach().shape)
                plt.imshow(fake_imgs[0].cpu().detach().permute(1, 2, 0))
                ############################
                # (3) Update D network
                ###########################
                netD.zero_grad()
                errD, errD_real, errD_wrong, errD_fake = \
                    compute_discriminator_loss(netD, real_imgs, fake_imgs,
                                               real_labels, fake_labels,
                                               mu, self.gpus)
                errD.backward()
                optimizerD.step()
                ############################
                # (2) Update G network
                ###########################
                netG.zero_grad()
                errG = compute_generator_loss(netD, fake_imgs,
                                              real_labels, mu, self.gpus)
                kl_loss = KL_loss(mu, logvar)
                errG_total = errG + kl_loss * args.KL
                errG_total.backward()
                optimizerG.step()
                
                br = br+1
                
                count = count + 1
                if i % 10 == 0:
                    '''summary_D = summary.scalar('D_loss', errD.data)
                    summary_D_r = summary.scalar('D_loss_real', errD_real)
                    summary_D_w = summary.scalar('D_loss_wrong', errD_wrong)
                    summary_D_f = summary.scalar('D_loss_fake', errD_fake)
                    summary_G = summary.scalar('G_loss', errG.data)
                    summary_KL = summary.scalar('KL_loss', kl_loss.data)

                    self.summary_writer.add_summary(summary_D, count)
                    self.summary_writer.add_summary(summary_D_r, count)
                    self.summary_writer.add_summary(summary_D_w, count)
                    self.summary_writer.add_summary(summary_D_f, count)
                    self.summary_writer.add_summary(summary_G, count)
                    self.summary_writer.add_summary(summary_KL, count)'''

                    # save the image result for each epoch
                    inputs = (txt_embedding, fixed_noise)
                    lr_fake, fake, _, _ = nn.parallel.data_parallel(netG, inputs, self.gpus)
                    print('real_img_cpu', real_img_cpu.shape)   # real_img_cpu torch.Size([128, 3, 64, 64])
                    #print('text_embedding:  ', txt_embedding)
                    print(type(real_img_cpu))
                    print(real_img_cpu[0].shape)
                    plt.imshow(real_img_cpu[0].permute(1, 2, 0))
                    #plt.imshow(real_img_cpu[1].numpy().squeeze(), cmap='RGB')
                    #plt.imshow(real_img_cpu) 
                    '''save_img_results(real_img_cpu, fake, epoch, self.image_dir)
                    if lr_fake is not None:
                        save_img_results(None, lr_fake, epoch, self.image_dir)'''
                print('br', br)
            end_t = time.time()
            c = 1
            print('''[%d/%d][%d/%d] Loss_D: %.4f Loss_G: %.4f Loss_KL: %.4f
                     Loss_real: %.4f Loss_wrong:%.4f Loss_fake %.4f
                     Total Time: %.2fsec
                  '''
                  % (epoch, self.max_epoch, i, len(data_loader),
                     errD.data, errG.data, kl_loss.data,
                     errD_real, errD_wrong, errD_fake, (end_t - start_t)))
            if epoch % self.snapshot_interval == 0:
                save_model(netG, netD, epoch, self.model_dir)
        #
        #save_model(netG, netD, self.max_epoch, self.model_dir)
        #
        #self.summary_writer.close()'''
        
    


# ------------------------------------------------  main.py --------------------------------------------------

import torch.backends.cudnn as cudnn
import torch
import torchvision.transforms as transforms

import argparse
import os
import random
import sys
import pprint
import datetime
import dateutil
import dateutil.tz
#import torchfile
    
class Struct:
    def __init__(self, **entries):
        self.__dict__.update(entries)

if __name__ == '__main__':
    params = dict()
    # parameters
    parser = argparse.ArgumentParser()
    params = dict()
    params['CONFIG_NAME']='stageII'
    params['DATASET_NAME']='coco'
    params['EMBEDDING_TYPE']='cnn-rnn'
    params['GPU_ID']='0'
    params['CUDA']='TRUE'
    params['WORKERS']=1
    params['NET_G']=''
                    #../input/models/coco_netg_epoch_90/coco_netG_epoch_90.pth
    params['NET_D']=''
    params['STAGE1_G']='/content/tmp/Model/netG_epoch_0.pth'
    params['DATA_DIR']='/content/coco14/coco'
    params['IMG_DIR'] = '/content/coco2014/train2014/train2014'
    params['VIS_COUNT']=64
    params['Z_DIM']=100
    params['IMSIZE']=256
    params['STAGE']=2
    #TRAIN = edict()
    params['FLAG']='TRUE'
    params['BATCH_SIZE']=32
    params['MAX_EPOCH']=1
    params['SNAPSHOT_INTERVAL']=1
    #params['PRETAINED_MODEL']=''
    #params['PRETRAINED_EPOCH']=600
    params['LR_DECAY_EPOCH']=20
    params['DISCRIMINATOR_LR']=0.0002
    params['GENERATOR_LR']=0.0002
    params['KL']=2.0
    #gan
    params['CONDITION_DIM']=128
    params['DF_DIM']=96
    params['GF_DIM']=192
    params['R_NUM']=2
    #text
    params['DIMENSION']=1024
    #params['manualSeed']=random.randint(1, 10000)
    args = Struct(**params) #Convert nested Python dict to object

   # s = Struct(**params)
   # config = s             # parser.parse_args()
   # print(config)
    manualSeed = random.randint(1, 10000)
    random.seed(manualSeed)
    torch.manual_seed(manualSeed)
    torch.cuda.manual_seed_all(manualSeed)
    now = datetime.datetime.now(dateutil.tz.tzlocal())
    timestamp = now.strftime('%Y_%m_%d_%H_%M_%S')
    print(timestamp)
    
    output_dir = 'tmp/'
    #output_dir = '../output/%s_%s_%s' % (args.DATASET_NAME, args.CONFIG_NAME, timestamp)
    print(output_dir)
    num_gpu = len(args.GPU_ID.split(','))
    if args.FLAG:
        image_transform = transforms.Compose([
            transforms.RandomCrop(args.IMSIZE),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
        dataset = TextDataset(args.DATA_DIR, 'train',
                              imsize=args.IMSIZE,
                              transform=image_transform)
        assert dataset
        dataloader = torch.utils.data.DataLoader(
            dataset, batch_size=args.BATCH_SIZE * num_gpu,
            drop_last=True, shuffle=True, num_workers=int(args.WORKERS))

        algo = GANTrainer(output_dir)
        algo.train(dataloader, args.STAGE)
# Out:
# 2022_12_11_22_40_08
# tmp/
# checking...
# Load filenames from: /content/coco14/coco/train/filenames.pickle (499)
# 499
# COCO_train2014_000000078077
# embedding....
# embeddings:  (499, 5, 1024)
# Load from:  /content/tmp/Model/netG_epoch_0.pth
# <ipython-input-56-f4b6accab9c7>:748: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   fixed_noise = Variable(torch.FloatTensor(batch_size, nz).normal_(0, 1),volatile=True)
# ---------------------
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([3, 256, 256])
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# real_img_cpu torch.Size([32, 3, 256, 256])
# <class 'torch.Tensor'>
# torch.Size([3, 256, 256])
# br 1
# ---------------------
# torch.Size([3, 256, 256])
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# br 2
# ---------------------
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([3, 256, 256])
# br 3
# [0/1][3/15] Loss_D: 25.8972 Loss_G: 5.3477 Loss_KL: 0.0034
#                      Loss_real: 4.9196 Loss_wrong:0.9804 Loss_fake 30.9762
#                      Total Time: 17.78sec
#
# Save G/D models
